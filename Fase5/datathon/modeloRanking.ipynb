# %%
import pandas as pd
import json
import string
import re
import nltk
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')

from nltk.tokenize import WordPunctTokenizer

from unidecode import unidecode

# %% [markdown]
# ### Primeiro vamos carregar o arquivo JSON

# %%
with open('prospects.json','r',encoding='utf-8') as file:
        dados_candidatos = json.load(file)

# %% [markdown]
# ## Agora iremos realizar o tratamento para separar o JSON em Tabela
#
# ### PROSPECTS.JSON
# #### Essa base são candidatos que realizaram candidaturas em determinadas vagas, temos uma coluna chamada situacao_candidato onde temos uma informação muito importante, se o candidato foi ou não contratado

# %%
info_candidaturas_vaga = []

for id_vaga,vaga_info in dados_candidatos.items():
    titulo_vaga = vaga_info.get('titulo','')
    modalidade_vaga = vaga_info.get('modalidade','')
    candidatura_vaga = vaga_info.get('prospects',[])

    for candidatura in candidatura_vaga:
        registro = {
            'id_vaga': id_vaga,
            'titulo_vaga': titulo_vaga,
            'modalidade_vaga': modalidade_vaga,
            'nome_candidato': candidatura.get('nome',''),
            'id_candidato': candidatura.get('codigo', ''),
            'situacao_candidado': candidatura.get('situacao_candidado', ''),
            'data_candidatura': candidatura.get('data_candidatura', ''),
            'ultima_atualizacao': candidatura.get('ultima_atualizacao', ''),
            'comentario': candidatura.get('comentario', ''),
            'recrutador': candidatura.get('recrutador', '')
        }

        info_candidaturas_vaga.append(registro)

# %%
df_candidaturas = pd.DataFrame(info_candidaturas_vaga)

# %%
df_candidaturas.head(3)
# Out:
#   id_vaga                                        titulo_vaga modalidade_vaga  \
# 0    4530                                CONSULTOR CONTROL M
# 1    4530                                CONSULTOR CONTROL M
# 2    4531  2021-2607395-PeopleSoft Application Engine-Dom...
#
#              nome_candidato id_candidato           situacao_candidado  \
# 0               José Vieira        25632  Encaminhado ao Requisitante
# 1  Srta. Isabela Cavalcante        25529  Encaminhado ao Requisitante
# 2     Sra. Yasmin Fernandes        25364     Contratado pela Decision
#
#   data_candidatura ultima_atualizacao  \
# 0       25-03-2021         25-03-2021
# 1       22-03-2021         23-03-2021
# 2       17-03-2021         12-04-2021
#
#                                           comentario         recrutador
# 0               Encaminhado para  - PJ R$ 72,00/hora  Ana Lívia Moreira
# 1  encaminhado para  - R$ 6.000,00 – CLT Full , n...  Ana Lívia Moreira
# 2                         Data de Inicio: 12/04/2021   Juliana Cassiano

# %%
df_candidaturas.tail(3)
# Out:
#       id_vaga                                       titulo_vaga  \
# 53756   14220  Consultor Sênior Especialista SAP LES-TRA - 1433
# 53757   14220  Consultor Sênior Especialista SAP LES-TRA - 1433
# 53758   14221           Consultor Sênior Oracle EPM FCCS - 1434
#
#       modalidade_vaga          nome_candidato id_candidato  \
# 53756                             Ana Cardoso        16828
# 53757                   Pedro Lucas das Neves        15042
# 53758                  Maria Eduarda Cassiano        49190
#
#                 situacao_candidado data_candidatura ultima_atualizacao  \
# 53756                     Desistiu       26-02-2025         28-02-2025
# 53757  Encaminhado ao Requisitante       28-02-2025         28-02-2025
# 53758                     Prospect       26-02-2025         26-02-2025
#
#                                               comentario    recrutador
# 53756  Recebeu a confirmação de outro processo seleti...   Elisa Nunes
# 53757                                                      Elisa Nunes
# 53758                                                     Luna Correia

# %% [markdown]
# ### APPLICANTS.JSON

# %%
with open('applicants.json','r',encoding='utf-8') as file:
    dados_candidatos = json.load(file)

info_candidatos = []

for candidato_id, candidato_info in dados_candidatos.items():
    infos_basicas = candidato_info.get('info_basicas',{})
    infos_prof = candidato_info.get('informacoes_profissionais',{})
    formacao = candidato_info.get('formacao_e_idiomas',{})

    registroCandidato = {
        'id_candidato': candidato_id,
        'cv_texto_pt': candidato_info.get('cv_pt', ''),
        'cv_texto_en': candidato_info.get('cv_en', ''),
        'applicant_area_atuacao': infos_prof.get('area_atuacao', ''),
        'applicant_conhecimentos': infos_prof.get('conhecimentos_tecnicos', ''),
        'applicant_certificacoes': infos_prof.get('certificacoes', ''),
        'applicant_nivel_profissional': infos_prof.get('nivel_profissional', ''),
        'applicant_nivel_academico': formacao.get('nivel_academico', ''),
        'applicant_nivel_ingles': formacao.get('nivel_ingles', ''),
        'applicant_nivel_espanhol': formacao.get('nivel_espanhol', ''),
        'applicant_nome': infos_basicas.get('nome', '')
        # Acredito que outros dados como e-mail, telefone, etc... não tem necessidade
    }

    info_candidatos.append(registroCandidato)


df_candidatos = pd.DataFrame(info_candidatos)

df_candidatos.head(3)
# Out:
#   id_candidato                                        cv_texto_pt cv_texto_en  \
# 0        31000  assistente administrativo\n\n\nsantosbatista\n...
# 1        31001  formação acadêmica\nensino médio (2º grau) em ...
# 2        31002  objetivo: área administrativa | financeira\n\n...
#
#   applicant_area_atuacao applicant_conhecimentos  \
# 0
# 1         Administrativa
# 2         Administrativa
#
#                              applicant_certificacoes  \
# 0
# 1
# 2  MS [77-418] MOS: Microsoft Office Word 2013, M...
#
#   applicant_nivel_profissional   applicant_nivel_academico  \
# 0
# 1                               Ensino Superior Incompleto
# 2                                 Ensino Superior Completo
#
#   applicant_nivel_ingles applicant_nivel_espanhol applicant_nome
# 0
# 1                 Nenhum                   Nenhum
# 2          Intermediário                   Básico

# %%
df_candidatos.tail(3)
# Out:
#       id_candidato cv_texto_pt cv_texto_en applicant_area_atuacao  \
# 42479         5997
# 42480         5998
# 42481         5999
#
#       applicant_conhecimentos applicant_certificacoes  \
# 42479
# 42480
# 42481
#
#       applicant_nivel_profissional applicant_nivel_academico  \
# 42479
# 42480
# 42481
#
#       applicant_nivel_ingles applicant_nivel_espanhol applicant_nome
# 42479
# 42480
# 42481

# %%
with open('vagas.json', 'r', encoding='utf-8') as file:
    vagas = json.load(file)


info_vagas = []


for id_vaga, vaga_info in vagas.items():
    info_basicas = vaga_info.get('informacoes_basicas', {})
    perfil = vaga_info.get('perfil_vaga', {})

    registro_vaga = {
        'id_vaga': id_vaga, # 
        'titulo_vaga_detalhado': info_basicas.get('titulo_vaga', ''),
        'cliente_vaga': info_basicas.get('cliente', ''),
        'tipo_contratacao': info_basicas.get('tipo_contratacao', ''),
        'pais_vaga': perfil.get('pais', ''),
        'estado_vaga': perfil.get('estado', ''),
        'cidade_vaga': perfil.get('cidade', ''),
        'nivel_profissional_vaga': perfil.get('nivel_profissional', ''),
        'nivel_academico_vaga': perfil.get('nivel_academico', ''),
        'nivel_ingles_vaga': perfil.get('nivel_ingles', ''),
        'nivel_espanhol_vaga': perfil.get('nivel_espanhol', ''),
        'areas_atuacao_vaga': perfil.get('areas_atuacao', ''),
        'atividades_vaga': perfil.get('principais_atividades', ''), 
        'competencias_vaga': perfil.get('competencia_tecnicas_e_comportamentais', ''), 
        'observacoes_vaga': perfil.get('demais_observacoes', ''),
        'pcd_vaga': perfil.get('vaga_especifica_para_pcd', '')
    }

    info_vagas.append(registro_vaga)


df_vagas = pd.DataFrame(info_vagas)

# %%
df_vagas.head(3)
# Out:
#   id_vaga   titulo_vaga_detalhado              cliente_vaga tipo_contratacao  \
# 0    5185        Operation Lead -  Morris, Moran and Dodson         CLT Full
# 1    5184  Consultor PP/QM Sênior  Morris, Moran and Dodson         CLT Full
# 2    5183   ANALISTA PL/JR C/ SQL  Morris, Moran and Dodson         CLT Full
#
#   pais_vaga estado_vaga cidade_vaga nivel_profissional_vaga  \
# 0    Brasil   São Paulo   São Paulo
# 1    Brasil   São Paulo   São Paulo
# 2    Brasil   São Paulo   São Paulo
#
#        nivel_academico_vaga nivel_ingles_vaga nivel_espanhol_vaga  \
# 0  Ensino Superior Completo          Avançado             Fluente
# 1  Ensino Superior Completo           Fluente              Nenhum
# 2  Ensino Superior Completo            Nenhum       Intermediário
#
#                   areas_atuacao_vaga  \
# 0       TI - Sistemas e Ferramentas-
# 1  TI - Desenvolvimento/Programação-
# 2       TI - Sistemas e Ferramentas-
#
#                                      atividades_vaga  \
# 0  Operations Lead\n\nRoles & Responsibilities:\n...
# 1  Consultor PP/QM Sr.\n\n• Consultor PP/QM Sênio...
# 2  Descrição – Atividades:\n\no Monitoramento das...
#
#                                    competencias_vaga  \
# 0  Required Skills:\n• Prior experience in Cloud ...
# 1  • Consultor PP/QM Sênior com experiencia em pr...
# 2  Requisitos mandatórios:\n\no Conhecimentos Téc...
#
#                                     observacoes_vaga pcd_vaga
# 0            100% Remoto Período – entre 5 – 6 meses      Não
# 1                   • Início: Imediato • Fim: Jan/22      Não
# 2  Localização: Remoto Perfil: Analista Pleno ou ...      Não

# %%
df_vagas.tail(3)
# Out:
#       id_vaga                          titulo_vaga_detalhado  \
# 14078   12366          964 - Assistente fiscal ou financeiro
# 14079   12365  966 - Analista pleno ou sênior de área fiscal
# 14080   12364  965 - Assistente ou analista de área contábil
#
#                     cliente_vaga       tipo_contratacao pais_vaga estado_vaga  \
# 14078  Glover, Warren and Norris  CLT Full, PJ/Autônomo    Brasil   São Paulo
# 14079  Glover, Warren and Norris  CLT Full, PJ/Autônomo    Brasil   São Paulo
# 14080  Glover, Warren and Norris  CLT Full, PJ/Autônomo    Brasil   São Paulo
#
#       cidade_vaga nivel_profissional_vaga      nivel_academico_vaga  \
# 14078   São Paulo                          Ensino Superior Completo
# 14079     Barueri                          Ensino Superior Completo
# 14080     Barueri                          Ensino Superior Completo
#
#       nivel_ingles_vaga nivel_espanhol_vaga areas_atuacao_vaga  \
# 14078            Básico              Básico     TI - Projetos-
# 14079            Básico              Básico     TI - Projetos-
# 14080            Básico              Básico     TI - Projetos-
#
#                                          atividades_vaga  \
# 14078  Qualificações técnicas: conhecimento básico em...
# 14079  Qualificações técnicas: apuração de impostos r...
# 14080  Qualificações técnicas: reconciliação de conta...
#
#                                        competencias_vaga  \
# 14078  Local: Alphaville, Barueri\nQual região: SP\nI...
# 14079  Local: Alphaville, Barueri, SP.\nQual região: ...
# 14080  Local: Alphaville, Barueri, SP.\nRegião: Grand...
#
#                                         observacoes_vaga pcd_vaga
# 14078  Modelo de trabalho: Hibrido, 3 vezes por seman...
# 14079  Modelo de trabalho: Hibrido, 3 vezes por seman...
# 14080  Modelo de trabalho: Hibrido, 3 vezes por seman...

# %% [markdown]
# #### Fazendo merge de PROSPECTS e APPLICANTS

# %%
df_final_temp = pd.merge(
    df_candidaturas,
    df_candidatos,
    on='id_candidato',
    how='left'
)
print("\nMerge df_candidaturas + df_candidatos -> df_final_temp: ")
df_final_temp.head(3)
# Out:
# Merge df_candidaturas + df_candidatos -> df_final_temp:
#   id_vaga                                        titulo_vaga modalidade_vaga  \
# 0    4530                                CONSULTOR CONTROL M
# 1    4530                                CONSULTOR CONTROL M
# 2    4531  2021-2607395-PeopleSoft Application Engine-Dom...
#
#              nome_candidato id_candidato           situacao_candidado  \
# 0               José Vieira        25632  Encaminhado ao Requisitante
# 1  Srta. Isabela Cavalcante        25529  Encaminhado ao Requisitante
# 2     Sra. Yasmin Fernandes        25364     Contratado pela Decision
#
#   data_candidatura ultima_atualizacao  \
# 0       25-03-2021         25-03-2021
# 1       22-03-2021         23-03-2021
# 2       17-03-2021         12-04-2021
#
#                                           comentario         recrutador  \
# 0               Encaminhado para  - PJ R$ 72,00/hora  Ana Lívia Moreira
# 1  encaminhado para  - R$ 6.000,00 – CLT Full , n...  Ana Lívia Moreira
# 2                         Data de Inicio: 12/04/2021   Juliana Cassiano
#
#                                          cv_texto_pt cv_texto_en  \
# 0  \ndados pessoais\nestado civil: casado\nidade:...
# 1  solteiro, 47 anos\n\nestrada meringuava, nº 17...
# 2  \n\nárea de atuação: lider de consultoria / ge...
#
#                               applicant_area_atuacao  \
# 0
# 1  TI - Governança, TI - Infraestrutura, TI - Pro...
# 2                                      TI - Projetos
#
#                              applicant_conhecimentos applicant_certificacoes  \
# 0
# 1
# 2  - PeopleSoft (PeopleTools 8.49, 8.53, 8.55, 8....
#
#   applicant_nivel_profissional applicant_nivel_academico  \
# 0
# 1                               Ensino Superior Completo
# 2                               Ensino Superior Completo
#
#   applicant_nivel_ingles applicant_nivel_espanhol applicant_nome
# 0
# 1          Intermediário                   Básico
# 2               Avançado            Intermediário

# %%
#Informações de vaga nesse outro merge
print(df_final_temp.columns)
print(df_vagas.columns)

df_final_temp['id_vaga'] = df_final_temp['id_vaga'].astype(str)
df_vagas['id_vaga'] = df_vagas['id_vaga'].astype(str)

df_final = pd.merge(
    df_final_temp,
    df_vagas,
    on='id_vaga',
    how='left'
)

print(df_final.columns)
print(df_final.head(3))
# Out:
# Index(['id_vaga', 'titulo_vaga', 'modalidade_vaga', 'nome_candidato',
#        'id_candidato', 'situacao_candidado', 'data_candidatura',
#        'ultima_atualizacao', 'comentario', 'recrutador', 'cv_texto_pt',
#        'cv_texto_en', 'applicant_area_atuacao', 'applicant_conhecimentos',
#        'applicant_certificacoes', 'applicant_nivel_profissional',
#        'applicant_nivel_academico', 'applicant_nivel_ingles',
#        'applicant_nivel_espanhol', 'applicant_nome'],
#       dtype='object')
# Index(['id_vaga', 'titulo_vaga_detalhado', 'cliente_vaga', 'tipo_contratacao',
#        'pais_vaga', 'estado_vaga', 'cidade_vaga', 'nivel_profissional_vaga',
#        'nivel_academico_vaga', 'nivel_ingles_vaga', 'nivel_espanhol_vaga',
#        'areas_atuacao_vaga', 'atividades_vaga', 'competencias_vaga',
#        'observacoes_vaga', 'pcd_vaga'],
#       dtype='object')
# Index(['id_vaga', 'titulo_vaga', 'modalidade_vaga', 'nome_candidato',
#        'id_candidato', 'situacao_candidado', 'data_candidatura',
#        'ultima_atualizacao', 'comentario', 'recrutador', 'cv_texto_pt',
#        'cv_texto_en', 'applicant_area_atuacao', 'applicant_conhecimentos',
#        'applicant_certificacoes', 'applicant_nivel_profissional',
#        'applicant_nivel_academico', 'applicant_nivel_ingles',
#        'applicant_nivel_espanhol', 'applicant_nome', 'titulo_vaga_detalhado',
#        'cliente_vaga', 'tipo_contratacao', 'pais_vaga', 'estado_vaga',
#        'cidade_vaga', 'nivel_profissional_vaga', 'nivel_academico_vaga',
#        'nivel_ingles_vaga', 'nivel_espanhol_vaga', 'areas_atuacao_vaga',
#        'atividades_vaga', 'competencias_vaga', 'observacoes_vaga', 'pcd_vaga'],
#       dtype='object')
#   id_vaga                                        titulo_vaga modalidade_vaga  \
# 0    4530                                CONSULTOR CONTROL M
# 1    4530                                CONSULTOR CONTROL M
# 2    4531  2021-2607395-PeopleSoft Application Engine-Dom...
#
#              nome_candidato id_candidato           situacao_candidado  \
# 0               José Vieira        25632  Encaminhado ao Requisitante
# 1  Srta. Isabela Cavalcante        25529  Encaminhado ao Requisitante
# 2     Sra. Yasmin Fernandes        25364     Contratado pela Decision
#
#   data_candidatura ultima_atualizacao  \
# 0       25-03-2021         25-03-2021
# 1       22-03-2021         23-03-2021
# 2       17-03-2021         12-04-2021
#
#                                           comentario         recrutador  ...  \
# 0               Encaminhado para  - PJ R$ 72,00/hora  Ana Lívia Moreira  ...
# 1  encaminhado para  - R$ 6.000,00 – CLT Full , n...  Ana Lívia Moreira  ...
# 2                         Data de Inicio: 12/04/2021   Juliana Cassiano  ...
#
#       cidade_vaga nivel_profissional_vaga      nivel_academico_vaga  \
# 0  Rio de Janeiro                          Ensino Superior Completo
# 1  Rio de Janeiro                          Ensino Superior Completo
# 2       São Paulo                             Ensino Médio Completo
#
#   nivel_ingles_vaga nivel_espanhol_vaga                    areas_atuacao_vaga  \
# 0            Nenhum              Nenhum     TI - Desenvolvimento/Programação-
# 1            Nenhum              Nenhum     TI - Desenvolvimento/Programação-
# 2            Nenhum              Nenhum  Gestão e Alocação de Recursos de TI-
#
#                                      atividades_vaga  \
# 0  - Experiência comprovada em projetos de control-M
# 1  - Experiência comprovada em projetos de control-M
# 2  Key skills required for the job are:\n\nPeople...
#
#                                    competencias_vaga  \
# 0  - Experiência comprovada em projetos de control-M
# 1  - Experiência comprovada em projetos de control-M
# 2  O recurso Peoplesoft tem como responsabilidade...
#
#                                     observacoes_vaga pcd_vaga
# 0  Contratação PJ Projeto pontual de 2 a 3 meses ...      Não
# 1  Contratação PJ Projeto pontual de 2 a 3 meses ...      Não
# 2      Remoto DEPOIS PRESENCIAL, TEMPO INDETERMINADO      Não
#
# [3 rows x 35 columns]

# %% [markdown]
# ### Features e Pré-Processamento

# %% [markdown]
# ##### Como tinhamos observado anteriormente, a coluna situacao_candidato é importante, onde indica se o candidato foi ou não aderente a vaga, vamos então separar da seguinte forma:
# ##### 1 -> Aderente
# ##### 0 -> Não aderente

# %%
# Visualizando o que temos na coluna situacao_candidato
df_final['situacao_candidado'].unique()
# Out:
# array(['Encaminhado ao Requisitante', 'Contratado pela Decision',
#        'Desistiu', 'Documentação PJ', 'Não Aprovado pelo Cliente',
#        'Prospect', 'Não Aprovado pelo RH', 'Aprovado',
#        'Não Aprovado pelo Requisitante', 'Inscrito', 'Entrevista Técnica',
#        'Em avaliação pelo RH', 'Contratado como Hunting',
#        'Desistiu da Contratação', 'Entrevista com Cliente',
#        'Documentação CLT', 'Recusado', 'Documentação Cooperado',
#        'Sem interesse nesta vaga', 'Encaminhar Proposta',
#        'Proposta Aceita'], dtype=object)

# %% [markdown]
# ## Mapeamento de Status para Variável Alvo ('situacao_candidado')
#
# ### Status Mapeados para 1 (Aderente):
#
# * 'Contratado pela Decision'
# * 'Contratado como Hunting'
# * 'Aprovado'
# * 'Proposta Aceita'
# * 'Documentação PJ'
# * 'Documentação CLT'
# * 'Documentação Cooperado'
# * 'Encaminhar Proposta'
#
# ### Status Mapeados para 0 (Não Aderente):
#
# * 'Não Aprovado pelo Cliente'
# * 'Não Aprovado pelo Requisitante'
# * 'Recusado'

# %%
df_final['situacao_candidado'].value_counts()
# Out:
# situacao_candidado
# Prospect                          20021
# Encaminhado ao Requisitante       16122
# Inscrito                           3980
# Não Aprovado pelo Cliente          3492
# Contratado pela Decision           2758
# Desistiu                           2349
# Não Aprovado pelo RH               1765
# Não Aprovado pelo Requisitante      765
# Entrevista Técnica                  579
# Sem interesse nesta vaga            576
# Entrevista com Cliente              469
# Em avaliação pelo RH                375
# Contratado como Hunting             226
# Aprovado                            209
# Desistiu da Contratação              59
# Documentação PJ                       4
# Documentação CLT                      3
# Recusado                              2
# Documentação Cooperado                2
# Encaminhar Proposta                   2
# Proposta Aceita                       1
# Name: count, dtype: int64

# %%
## fazer um dicionario
dic_map_situacao_candidato = {
    'Contratado pela Decision': 1,
    'Contratado como Hunting': 1,
    'Aprovado': 1,           
    'Proposta Aceita': 1,    
    'Documentação PJ': 1,    
    'Documentação CLT': 1,   
    'Documentação Cooperado': 1, 
    'Encaminhar Proposta': 1, 
    'Não Aprovado pelo Cliente': 0,   
    'Não Aprovado pelo Requisitante': 0,  
    'Recusado': 0
}

# %%
dic_map_situacao_candidato
# Out:
# {'Contratado pela Decision': 1,
#  'Contratado como Hunting': 1,
#  'Aprovado': 1,
#  'Proposta Aceita': 1,
#  'Documentação PJ': 1,
#  'Documentação CLT': 1,
#  'Documentação Cooperado': 1,
#  'Encaminhar Proposta': 1,
#  'Não Aprovado pelo Cliente': 0,
#  'Não Aprovado pelo Requisitante': 0,
#  'Recusado': 0}

# %%
# Criando uma coluna para determinar aderente a vaga ou não
df_final['aderente'] = df_final['situacao_candidado'].map(dic_map_situacao_candidato)
linhas_com_nan = df_final['aderente'].isnull().sum()
print(linhas_com_nan)
df_final.dropna(subset=['aderente'],inplace=True)
df_final['aderente'] = df_final['aderente'].astype(int)
# Out:
# 46295

# %%
df_final.shape
# Out:
# (7464, 73)

# %%
df_final['aderente'].isna().sum()
# Out:
# 0

# %%
df_final.head(3)
# Out:
#   id_vaga                                        titulo_vaga modalidade_vaga  \
# 2    4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 4    4533  2021-2605708-Microfocus Application Life Cycle...
# 6    4534  2021-2605711-Microfocus QTP - UFT Automation T...
#
#           nome_candidato id_candidato        situacao_candidado  \
# 2  Sra. Yasmin Fernandes        25364  Contratado pela Decision
# 4         Arthur Almeida        26338  Contratado pela Decision
# 6       Ana Luiza Vieira        26361           Documentação PJ
#
#   data_candidatura ultima_atualizacao                           comentario  \
# 2       17-03-2021         12-04-2021           Data de Inicio: 12/04/2021
# 4       29-04-2021         18-05-2021
# 6       28-04-2021         11-05-2021  Aguardando confirmação de inicio _
#
#           recrutador  ... nivel_profissional_vaga   nivel_academico_vaga  \
# 2   Juliana Cassiano  ...                          Ensino Médio Completo
# 4      Stella Vieira  ...                          Ensino Médio Completo
# 6  Manuella Carvalho  ...                          Ensino Médio Completo
#
#   nivel_ingles_vaga nivel_espanhol_vaga                    areas_atuacao_vaga  \
# 2            Nenhum              Nenhum  Gestão e Alocação de Recursos de TI-
# 4           Técnico             Fluente  Gestão e Alocação de Recursos de TI-
# 6           Técnico              Nenhum  Gestão e Alocação de Recursos de TI-
#
#                                      atividades_vaga  \
# 2  Key skills required for the job are:\n\nPeople...
# 4  Arquiteto\n\nFoco na área e automação.\n\nRequ...
# 6  Automação de teste (conhecimento do código)\n\...
#
#                                    competencias_vaga  \
# 2  O recurso Peoplesoft tem como responsabilidade...
# 4  Arquiteto\n\nFoco na área e automação.\n\nRequ...
# 6  Automação de teste (conhecimento do código)\n\...
#
#                                     observacoes_vaga pcd_vaga aderente
# 2      Remoto DEPOIS PRESENCIAL, TEMPO INDETERMINADO      Não        1
# 4  Atuação somente em horário comercial. Tempo in...      Não        1
# 6                                                         Não        1
#
# [3 rows x 36 columns]

# %%
print(df_final['aderente'].value_counts(normalize=True))
# Out:
# aderente
# 0    0.570606
# 1    0.429394
# Name: proportion, dtype: float64

# %%
# temos um problema, a maioria dos dados são de pessoas que não foram contratadas 94%
# isso pode ter um problema no momento do treino pelo fato de esta desbalanceado
print(df_final['aderente'].value_counts())
# Out:
# aderente
# 0    4259
# 1    3205
# Name: count, dtype: int64

# %%
df_final.columns
# Out:
# Index(['id_vaga', 'titulo_vaga', 'modalidade_vaga', 'nome_candidato',
#        'id_candidato', 'situacao_candidado', 'data_candidatura',
#        'ultima_atualizacao', 'comentario', 'recrutador', 'cv_texto_pt',
#        'cv_texto_en', 'applicant_area_atuacao', 'applicant_conhecimentos',
#        'applicant_certificacoes', 'applicant_nivel_profissional',
#        'applicant_nivel_academico', 'applicant_nivel_ingles',
#        'applicant_nivel_espanhol', 'applicant_nome', 'titulo_vaga_detalhado',
#        'cliente_vaga', 'tipo_contratacao', 'pais_vaga', 'estado_vaga',
#        'cidade_vaga', 'nivel_profissional_vaga', 'nivel_academico_vaga',
#        'nivel_ingles_vaga', 'nivel_espanhol_vaga', 'areas_atuacao_vaga',
#        'atividades_vaga', 'competencias_vaga', 'observacoes_vaga', 'pcd_vaga',
#        'aderente'],
#       dtype='object')

# %%
def limpar_texto(texto):
    # verifica se é uma string
    if not isinstance(texto,str):
        return ""
    texto = texto.lower()
    # remover espaços/quebras de linha
    texto = re.sub(r'\s+',' ',texto).strip()
    # remover pontuação
    texto = re.sub(r'[' + re.escape(string.punctuation) + r']','',texto)
    # remover espaços inicio e fim
    texto = texto.strip()
    # remover acentos
    texto = unidecode(texto)
    
    return texto

colunas_texto = ['cv_texto_pt','cv_texto_en',
                 'applicant_conhecimentos',
                 'applicant_certificacoes',
                 'atividades_vaga',
                 'competencias_vaga',
                 'titulo_vaga_detalhado',
                 'observacoes_vaga',
                 'comentario']


for col in colunas_texto:
    nova_coluna = col + '_limpo'
    print(f"Limpando a coluna: {col} -> {nova_coluna}")
    df_final[nova_coluna] = df_final[col].apply(limpar_texto)
# Out:
# Limpando a coluna: cv_texto_pt -> cv_texto_pt_limpo
# Limpando a coluna: cv_texto_en -> cv_texto_en_limpo
# Limpando a coluna: applicant_conhecimentos -> applicant_conhecimentos_limpo
# Limpando a coluna: applicant_certificacoes -> applicant_certificacoes_limpo
# Limpando a coluna: atividades_vaga -> atividades_vaga_limpo
# Limpando a coluna: competencias_vaga -> competencias_vaga_limpo
# Limpando a coluna: titulo_vaga_detalhado -> titulo_vaga_detalhado_limpo
# Limpando a coluna: observacoes_vaga -> observacoes_vaga_limpo
# Limpando a coluna: comentario -> comentario_limpo

# %%
print(df_final.columns)
# Out:
# Index(['id_vaga', 'titulo_vaga', 'modalidade_vaga', 'nome_candidato',
#        'id_candidato', 'situacao_candidado', 'data_candidatura',
#        'ultima_atualizacao', 'comentario', 'recrutador', 'cv_texto_pt',
#        'cv_texto_en', 'applicant_area_atuacao', 'applicant_conhecimentos',
#        'applicant_certificacoes', 'applicant_nivel_profissional',
#        'applicant_nivel_academico', 'applicant_nivel_ingles',
#        'applicant_nivel_espanhol', 'applicant_nome', 'titulo_vaga_detalhado',
#        'cliente_vaga', 'tipo_contratacao', 'pais_vaga', 'estado_vaga',
#        'cidade_vaga', 'nivel_profissional_vaga', 'nivel_academico_vaga',
#        'nivel_ingles_vaga', 'nivel_espanhol_vaga', 'areas_atuacao_vaga',
#        'atividades_vaga', 'competencias_vaga', 'observacoes_vaga', 'pcd_vaga',
#        'aderente', 'cv_texto_pt_limpo', 'cv_texto_en_limpo',
#        'applicant_conhecimentos_limpo', 'applicant_certificacoes_limpo',
#        'atividades_vaga_limpo', 'competencias_vaga_limpo',
#        'titulo_vaga_detalhado_limpo', 'observacoes_vaga_limpo',
#        'comentario_limpo'],
#       dtype='object')

# %%
print("Curriculo Original: \n",df_final.loc[2,'cv_texto_pt']) # mostrando os caracateres do primeiro currículo antes da transformação
# Out:
# Curriculo Original:
#
#
# área de atuação: lider de consultoria / gerenciamento de projeto / liderança técnica / analista senior
# resumo de qualificações
# - profissional com 30 anos de experiência na área de ti, adquirida em projetos desenvolvidos em empresas nacionais de grande porte e consultorias especializadas.
# - sólida experiência na área de tecnologia da informação atuando como consultor pleno-senior, liderando equipes de desenvolvimento, implantação e upgrade de sistemas erp, crm, hcm e campus solution.
# - sólida experiência em implantação de novas funcionalidades e backoffice à solução peoplesoft.
# - forte atuação junto a clientes internos e externos para implantação de novos processos de negócio através de soluções erp – crm e hcm.
# - vivência nos processos de integração entre módulos do peoplesoft e sistemas externos e internos.
# - experiência em ferramentas para gerenciamento de projetos (msproject e hp ppm).
# - experiência em consultoria remota e monitoramento de processos de produção à distância.
# - vivência nos processos de análise e levantamento de requisitos, detalhamento de escopo, definição de arquitetura, elaboração de especificações técnicas/funcionais e implantação de processos de produção.
# - experiência na administração do ambiente e nos processos de administração de acessos e perfis.
# - sólida experiência no suporte a produção, administração de chamados e riscos, apresentação de scorecard semanal e realização de treinamento.
#
#
# formação
# - graduação – universidade castelo branco – tecnólogo em processamento de dados – 1995
#
#
# capacitação técnica
# - peoplesoft (peopletools 8.49, 8.53, 8.55, 8.57 peoplecode, sqr, crystal, xml publisher, query manager, app engine, app package, process scheduler, segurança, app message, integration broker, workflow, tree manager)
# - peoplesoft fscm 8.9, 9.1 hcm 9.0, 9.2, crm e cs
# - microsoft visual basic, java, xml, javascript, html, css, jquery, python
# - ios, windows, linux, unix
# - microsoft sql server, microsoft access, mysql, oracle.
# - oracle pl/sql, procedures, triggers.
# - oracle oic
#
#
# cursos de extensão
# - microsoft visual basic – nsi – 1995
# - trailhead playground management – trailhead by salesforce – dez-2019
# - noções básicas do trailhead – trailhead by salesforce – dez-2019
# - data modeling – trailhead by salesforce – dez-2019
# - salesforce platform basics – trailhead by salesforce – jan-2020
# - crm for salesforce classic - trailhead by salesforce – jan-2020
#
#
# idiomas
# - inglês – avançado
# - espanhol – intermediário
# - português - nativo
#
# certificados
# - capacitação peoplesoft (formação técnica) – peoplesoft -1999
# - segurança da informação – brasilcap – 2009
# - ad (administração de dados) brasilcap– 2010
# - oracle hcm cloud 2019 sales specialist assessment – ago-2020
# - oracle hcm cloud solution engineer specialist – jul-2020
# - scrum foundation professional certificate (spfc) – certiprof – jul-2020
# - oracle integration cloud services oic – oracle ics – udemy – dez-2020
#
#
# principais projetos
# - implementação da suíte financeira do peoplesoft erp na mbr – bh (atual vale), atuando diretamente nos módulos: ap, ar e tr como consultor técnico sênior.
# - implantação da solução oracle peoplesoft erp e crm na aga linde health care - rj, atuando na frente técnica, parametrizando, customizando e desenvolvendo interfaces.
# - implantação de solução oracle peoplesoft erp na porto seguro seguros – sp, atuando diretamente no módulo ap como consultor sênior e líder de equipe. atuei diretamente na construção das interfaces entre o peoplesoft e o sistema legado.
# - implantação da solução oracle peoplesoft na tavex – sp, atuando diretamente como consultor técnico sênior.
# - implantação da resolução 533 da anatel no peoplesoft crm 2012 na claro – sp.
# - implantação de interface na vale (escritório: piura - peru) entre o peoplesoft hcm e o adam (sistema de folha de pagamento) utilizado no peru.
# - implantação peoplesoft hcm 92 na bbts - rj
# - projeto cobrança registrada (peoplesoft fscm – ar) realizado na sulamérica – rj
# - sustentação peoplesoft hcm 92 na vale brasil – rj
# - rollout oracle peoplesoft fscm 91 na cbre brasil - sp
#
#
# experiência profissional
# dbs-digital– jan/2021
# projeto laureate – criação de novas bu gl
# - responsável pelo acompanhamento dos testes em uat1/uat2
# - ajustes técnicos para os chamados abertos em uat1/uat2
# - manutenção em integrações com oic erp cloud/erp on premise
#
#
# ataway– fev/2020 – dez/2020
# projeto global cbre – implantação do peoplesoft fin 91 – projeto remoto
# - responsável pelo módulo de compras (po)
# - levantamento dos requisitos
# - workshop das funcionalidades
# - levantamento de integrações entre peoplesoft e coupa system
# - testes unitários e testes integrados
# - treinamento
#
# projeto br distribuidora – integração oracle oic– projeto remoto
# - manutenção em integrações hcm cloud/erp
# - criação de novas integrações. mapeamentos de dados e regras de conversão
#
#
#
# grupo quanam– jun/2019 – dez/19
# projeto revitalização peoplesoft fin 9.1– santista - sp
# - levantamento funcional/técnico de um módulo adicional (cotton) a ser incorporado ao peoplesoft.
# este módulo contempla todo o fluxo de compra e venda de algodão. a versão anterior havia sido escrito em clipper.
# - atuação técnica nos módulos: contas a pagar, compras, inventário e fretes
# - estimativa de tempo baseado em planilha excel com valores padrão para todos os tipos de objetos peoplesoft para gaps novos e gaps de manutenção
# - conversão de processos antigos sqr em novos processos app. engine utilizando app packages
# - conversão de relatórios crystal reports em xml publisher
# - manutenção de rotinas em pl/sql
#
#
# oracle do brasil – abr/2017 – maio-2019
# sustentação pós-implementação peoplesoft hcm 92 na vale (brasil) – rj
# - auxilio na comunicação entre o cliente e o time off-shore (índia).
# - acompanhamento das atividades dos usuários
# - acompanhamento das definições de novas atividades (melhorias)
# - levantamento de dados para pmo
# - melhoria das integrações (inbound & outbound) através de webservices e batch process
# - levantamento/analise/solução proposta da migração de sistema externo para dentro do peoplesoft
# - migração de projetos com o peoplesoft cemli manager
# - manutenção de novos projetos com o ppm ( project portfolio management )
# - acompanhamento nas atualizações de sistemas externos e adequação das rotinas pl/sql para atender as novas versões
# - ajuste e monitoramento da interface de folha de pagamento entre psft x fpw
#
#
# stefanini consultoria – jun/2016 – mar/2017
# atuando no projeto cobrança registrada na sulamérica – rj
# - realizando tarefas de configuração bancária, mapas bancários, geração de boletos impressos e emissão de boletos online. validando arquivos bancários e preparando arquivos de retorno aos bancos. geração e validação de código de barra e linha digitável
# - manutenção de rotinas em pl/sql (procedures, functions e triggers)
#
#
# f2c (a hitachi consulting company) – jun/2015 – jun/2016
# - atuei no desenvolvimento dos gaps principais (incluindo fluid page) e as interfaces entre o peoplesoft e o ebs, assim como entre o peoplesoft e o sistema legado.
# - construção de rotinas em pl/sql
#
#
# infosys – mai/2012 a mai/2015
# - suporte a produção para o peoplesoft hcm 9.0 (core hr, benefícios básicos) para a vale peru e chile:
# - atendimento e manutenção de chamados
# - desenvolvimento de melhorias
# - implementação de novas interfaces
# - manutenção em rotinas pl/sql (procedures, functions e triggers)
#
#
#
# limine solutions – nov/2011 a abr/2012
# - implantação da resolução 533 da anatel no peoplesoft crm 2012 na claro – sp
# - desenvolvimento de melhorias
# - construção de especificação técnica
# - modificação de stored procedures e functions
# - construção dos cenários de teste
# - desenvolvimento, testes unitários, testes de aceite do usuário e migração do projeto para ambiente produtivo
#
#
# contrato independente – fev/2011 a nov/2011
# - consultor técnico peoplesoft hcm no magazine luiza - sp:
# - desenvolvimento técnico remoto baseado em pacotes de especificação previamente construídas
# - desenvolvimento de novas funcionalidades, testes e migração dos projetos para ambiente de homologação.
#
# grupo quanam – jan/2006 a nov/2011
# mar/2011 a nov/2011
# - atuei diretamente no suporte a produção em conjunto com a equipe funcional e técnica:
# - construção de novas especificações
# - desenvolvimento e ajustes de interfaces
# - treinamento funcional e técnico
# - manutenção de rotinas em pl/sql
#
# peoplesoft back office na porto seguro seguros – sp (mar/2009 a jun/2009)
# consultor funcional / técnico:
# - desenvolvimento de novos gaps
# - administração de back office
# - atualização do processo de interface para o contas a pagar
#
# implementação da solução oracle peoplesoft erp na tavex – sp (jan/2009 a mar/2009)
# - consultor funcional / técnico:
# - desenvolvimento de novos gaps
# - implementação dos módulos: ap, ar, cm, gl, bi, ex, om, po, in e mn
# - construção de relatórios em sqr e crystal report.
#
# implementação da solução oracle peoplesoft erp na sul américa seguros – rj (jul/2008 a dec/2008)
# - consultor técnico:
# - implementação dos módulos: ap e ar
# - liderança e desenvolvimento de novos gaps
# - construção e manutenção da planilha de atividades
#
# - adaptando e recustomizando gaps da versão anterior
# - validação das definições de projeto
# - migração das definições de projeto
# - export/import de dados via data mover
# - criação e manutenção da planilha de trabalho
#
# implantação do peoplesoft financial 8.20 na porto seguro seguros – sp (segunda fase) (jan/2006 a dez/2007)
# - consultor funcional/técnico e líder técnico:
# - construção de especificações funcionais e técnicas para os gaps
# - construção de especificações funcionais e técnicas para as interfaces
# - desenvolvimento de gaps
# - desenvolvimento de interfaces entre peoplesoft e sistema legado
# - construção da documentação técnica
# - capacitação de novos consultores
# - treinamento do usuário nos processos de interface
#
#
# brazilcap - rj – jul/2009 a fev/2011
# - suporte funcional e técnico ao ambiente de produção e implementação de novas melhorias. revisão e reconstrução dos processos críticos do peoplesoft erp e hr:
# - revisão dos processos de produção
# - suporte as demandas de produção
# - construção e desenvolvimento de especificações e gaps para os módulos: ap, gl, am e hr
# - coordenação interna de treinamento técnico para a equipe técnica e novos empregados nos processos peoplesoft.
# - confeccionar especificações para a implementação do sap e desligamento do peoplesoft
# - construção de um novo processo de interface para o ap usando java
# - administração de entrevistas com consultorias externas para a implementação do sap
#
#
# ogeda it solutions – sp – jul/2004 a ago/2005
# - primeira fase da implementação do peoplesoft financial 8.20 na porto seguro seguros – sp. substituição do sistema legado construído em 4gl pelo oracle peoplesoft:
# - identificação de novas funcionalidades
# - construção de especificações funcionais e técnicas para os gaps
# - construção de especificações funcionais e técnicas para as interfaces
# - desenvolvimento de gaps
# - desenvolvimento de interfaces entre peoplesoft e sistema legado
#
#
# atos origin/peoplefriend – rj – dez/2003 a jun/2004
# - suporte a produção na shell brasil:
# - suporte as demandas de produção
# - extração e importação de dados com o data mover para o peoplesoft hr
# - desenvolvimento de novos gaps
# - extração de dados do peoplesoft para a base de dados do sap
#
#
# adoption/hg global – rj – mar/2003 a nov/2003
# - implementação do peoplesoft erp e crm e construção da integração entre as duas soluções na aga linde healthcare
# - análise de gaps
# - definição das tabelas depara para a interface
# - desenvolvimento de especificações técnicas
# - desenvolvimento de gaps no erp e crm
# - desenvolvimento dos programas de interface com sqr para o erp e o crm (cliente, contratos e field service)
#
#
# atos origin/peoplefriend – rj – jun/2002 a fev/2003
# - suporte a produção na shell brasil:
# - suporte as demandas de produção
# - desenvolvimento e manutenção de sqr e peoplecode
#
#
# hqs consulting – rj/sp – dez/1999 a fev/2002
# - suporte ao peoplesoft hr de produção na michellin – rj. atuei em parceria técnica com a deloitte:
# - desenvolvimento de novos relatórios utilizando sqr e crystal report
# - desenvolvimento de novas querys com o query manager
# - importação de dados com o data mover
#
# - implementação da suíte financeira do peoplesoft 7.5 em parceria com a pricewaterhousecoopers na mbr - bh:
# - desenvolvimento de novos gaps para o ap, ar e tr.
# - desenvolvimento de novos relatórios com sqr e crystal report
# - desenvolvimento de interface para o ap e ar
# - coordenação de atividades técnicas
#
# - suporte ao peoplesoft hr 7.5 de produção em parceria com a hunter group na gm (general motors) - sp:
# - desenvolvimento de novos relatórios com sqr e crystal report
# - extração de dados para a equipe de sap
#
# - suporte técnico ao peoplesoft 7.5 de produção na sul américa seguros - rj:
# - desenvolvimento de novos relatórios com nvision e query manager
# - revisão e reconstrução da árvore de departamentos
#
# - suporte técnico ao peoplesoft 7.5 de produção na companhia de seguros aliança do brasil - rj:
# - desenvolvimento de gaps para: ap, ar, po, gl e hr
# - desenvolvimento de novas interfaces para: ap, ar, po, gl e hr

# %%
colunas_limpas = [col + '_limpo' for col in colunas_texto if col in df_final.columns]
print(colunas_limpas)
tokenizer = WordPunctTokenizer() # Instancia o tokenizer

for col in colunas_limpas:
    nova_coluna_tokens = col.replace('_limpo','_tokens')
    print(f'Tokenizando a coluna: {col} -> {nova_coluna_tokens}')
    df_final[nova_coluna_tokens] = df_final[col].apply(lambda texto: tokenizer.tokenize(texto) if pd.notna(texto) else [])
# Out:
# ['cv_texto_pt_limpo', 'cv_texto_en_limpo', 'applicant_conhecimentos_limpo', 'applicant_certificacoes_limpo', 'atividades_vaga_limpo', 'competencias_vaga_limpo', 'titulo_vaga_detalhado_limpo', 'observacoes_vaga_limpo', 'comentario_limpo']
# Tokenizando a coluna: cv_texto_pt_limpo -> cv_texto_pt_tokens
# Tokenizando a coluna: cv_texto_en_limpo -> cv_texto_en_tokens
# Tokenizando a coluna: applicant_conhecimentos_limpo -> applicant_conhecimentos_tokens
# Tokenizando a coluna: applicant_certificacoes_limpo -> applicant_certificacoes_tokens
# Tokenizando a coluna: atividades_vaga_limpo -> atividades_vaga_tokens
# Tokenizando a coluna: competencias_vaga_limpo -> competencias_vaga_tokens
# Tokenizando a coluna: titulo_vaga_detalhado_limpo -> titulo_vaga_detalhado_tokens
# Tokenizando a coluna: observacoes_vaga_limpo -> observacoes_vaga_tokens
# Tokenizando a coluna: comentario_limpo -> comentario_tokens

# %%
df_final.head(3)
# Out:
#   id_vaga                                        titulo_vaga modalidade_vaga  \
# 2    4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 4    4533  2021-2605708-Microfocus Application Life Cycle...
# 6    4534  2021-2605711-Microfocus QTP - UFT Automation T...
#
#           nome_candidato id_candidato        situacao_candidado  \
# 2  Sra. Yasmin Fernandes        25364  Contratado pela Decision
# 4         Arthur Almeida        26338  Contratado pela Decision
# 6       Ana Luiza Vieira        26361           Documentação PJ
#
#   data_candidatura ultima_atualizacao                           comentario  \
# 2       17-03-2021         12-04-2021           Data de Inicio: 12/04/2021
# 4       29-04-2021         18-05-2021
# 6       28-04-2021         11-05-2021  Aguardando confirmação de inicio _
#
#           recrutador  ...                  comentario_limpo  \
# 2   Juliana Cassiano  ...           data de inicio 12042021
# 4      Stella Vieira  ...
# 6  Manuella Carvalho  ...  aguardando confirmacao de inicio
#
#                                   cv_texto_pt_tokens cv_texto_en_tokens  \
# 2  [area, de, atuacao, lider, de, consultoria, ge...                 []
# 4  [solteiro, brasileiro, 21061987, habilitacao, ...                 []
# 6  [alta, mobilidade, para, mudancas, e, viagens,...                 []
#
#                       applicant_conhecimentos_tokens  \
# 2  [peoplesoft, peopletools, 849, 853, 855, 857, ...
# 4                                                 []
# 6                                                 []
#
#   applicant_certificacoes_tokens  \
# 2                             []
# 4                             []
# 6                             []
#
#                               atividades_vaga_tokens  \
# 2  [key, skills, required, for, the, job, are, pe...
# 4  [arquiteto, foco, na, area, e, automacao, requ...
# 6  [automacao, de, teste, conhecimento, do, codig...
#
#                             competencias_vaga_tokens  \
# 2  [o, recurso, peoplesoft, tem, como, responsabi...
# 4  [arquiteto, foco, na, area, e, automacao, requ...
# 6  [automacao, de, teste, conhecimento, do, codig...
#
#                         titulo_vaga_detalhado_tokens  \
# 2  [20212607395peoplesoft, application, enginedom...
# 4  [20212605708microfocus, application, life, cyc...
# 6  [20212605711microfocus, qtp, uft, automation, ...
#
#                              observacoes_vaga_tokens  \
# 2  [remoto, depois, presencial, tempo, indetermin...
# 4  [atuacao, somente, em, horario, comercial, tem...
# 6                                                 []
#
#                        comentario_tokens
# 2           [data, de, inicio, 12042021]
# 4                                     []
# 6  [aguardando, confirmacao, de, inicio]
#
# [3 rows x 54 columns]

# %%
print("Verificar limpeza:", df_final['cv_texto_pt_limpo'].iloc[0][:100])
# Out:
# Verificar limpeza: area de atuacao lider de consultoria  gerenciamento de projeto  lideranca tecnica  analista senior r

# %%
print("Verificar tokens:", df_final['cv_texto_pt_tokens'].iloc[0][:100])
# Out:
# Verificar tokens: ['area', 'de', 'atuacao', 'lider', 'de', 'consultoria', 'gerenciamento', 'de', 'projeto', 'lideranca', 'tecnica', 'analista', 'senior', 'resumo', 'de', 'qualificacoes', 'profissional', 'com', '30', 'anos', 'de', 'experiencia', 'na', 'area', 'de', 'ti', 'adquirida', 'em', 'projetos', 'desenvolvidos', 'em', 'empresas', 'nacionais', 'de', 'grande', 'porte', 'e', 'consultorias', 'especializadas', 'solida', 'experiencia', 'na', 'area', 'de', 'tecnologia', 'da', 'informacao', 'atuando', 'como', 'consultor', 'plenosenior', 'liderando', 'equipes', 'de', 'desenvolvimento', 'implantacao', 'e', 'upgrade', 'de', 'sistemas', 'erp', 'crm', 'hcm', 'e', 'campus', 'solution', 'solida', 'experiencia', 'em', 'implantacao', 'de', 'novas', 'funcionalidades', 'e', 'backoffice', 'a', 'solucao', 'peoplesoft', 'forte', 'atuacao', 'junto', 'a', 'clientes', 'internos', 'e', 'externos', 'para', 'implantacao', 'de', 'novos', 'processos', 'de', 'negocio', 'atraves', 'de', 'solucoes', 'erp', '-', 'crm', 'e']

# %% [markdown]
# ### Removendo STOPWORDS (de,a,o,que)

# %%
nltk.download('stopwords')
stopwords_pt = nltk.corpus.stopwords.words('portuguese')
# Out:
# [nltk_data] Downloading package stopwords to c:\Users\Menacho\anaconda
# [nltk_data]     3\envs\ambienteposfiap\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords_pt
# Out:
# ['a',
#  'à',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'às',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'é',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'éramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'está',
#  'estamos',
#  'estão',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estávamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estivéramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéssemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'fôramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fôssemos',
#  'fui',
#  'há',
#  'haja',
#  'hajam',
#  'hajamos',
#  'hão',
#  'havemos',
#  'haver',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houverá',
#  'houveram',
#  'houvéramos',
#  'houverão',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houveríamos',
#  'houvermos',
#  'houvesse',
#  'houvessem',
#  'houvéssemos',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'não',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nós',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'são',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'ser',
#  'será',
#  'serão',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'seríamos',
#  'seu',
#  'seus',
#  'só',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'também',
#  'te',
#  'tem',
#  'tém',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terá',
#  'terão',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tínhamos',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tivéramos',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos']

# %%
type(stopwords_pt)
# Out:
# list

# %%
def remover_stopwords(lista_tokens,stopwords):
    if not isinstance(lista_tokens,list): # verifica se realmente é uma lista
        return []
    tokens_sem_stopwords = [token for token in lista_tokens if token not in stopwords and len(token) > 1] # Aqui removemos stopwords e também tokens de 1 letra
    return tokens_sem_stopwords


#Utilizar as colunas que possuem tokens no final
colunas_tokens = [col for col in df_final.columns if '_tokens' in col]
print(colunas_tokens)
#Para pecorrer uma lista demora muito, vamos utilizar set para transforma-lo em um estrutura de dados onde o python usa uma técnica eficiente ( tabela hash )
stopwords_set = set(stopwords_pt)
print(stopwords_set)

for col in colunas_tokens:
    coluna_nostop = col.replace('_tokens','_nostop')
    print(f"Removendo stopwords de: {col} -> {coluna_nostop}")
    df_final[coluna_nostop] = df_final[col].apply(lambda tokens: remover_stopwords(tokens,stopwords_set))
# Out:
# ['cv_texto_pt_tokens', 'cv_texto_en_tokens', 'applicant_conhecimentos_tokens', 'applicant_certificacoes_tokens', 'atividades_vaga_tokens', 'competencias_vaga_tokens', 'titulo_vaga_detalhado_tokens', 'observacoes_vaga_tokens', 'comentario_tokens']
# {'esse', 'tenha', 'forem', 'formos', 'éramos', 'seriam', 'só', 'era', 'seja', 'tenho', 'seremos', 'tinham', 'tiveram', 'teu', 'tiverem', 'houvermos', 'serão', 'há', 'este', 'seu', 'tenhamos', 'tivesse', 'já', 'esses', 'fui', 'seríamos', 'houveríamos', 'hajam', 'houveria', 'seus', 'estavam', 'depois', 'tuas', 'estiveram', 'seria', 'um', 'fôramos', 'mais', 'terão', 'esta', 'isto', 'nossas', 'ser', 'também', 'estiver', 'lhes', 'sou', 'vocês', 'esteve', 'que', 'no', 'tivermos', 'fôssemos', 'terei', 'tivéssemos', 'hajamos', 'delas', 'está', 'dela', 'ao', 'estivemos', 'foi', 'pelos', 'ou', 'aquelas', 'o', 'estivéramos', 'aquela', 'como', 'eles', 'estivesse', 'do', 'até', 'dos', 'houverem', 'estávamos', 'suas', 'estar', 'haja', 'dele', 'nossos', 'num', 'em', 'for', 'tem', 'estivermos', 'houvessem', 'serei', 'mas', 'estivessem', 'houveram', 'estivera', 'você', 'estão', 'aquele', 'das', 'sua', 'entre', 'me', 'quando', 'as', 'aos', 'e', 'houveriam', 'vos', 'teria', 'às', 'nem', 'tua', 'houver', 'estes', 'sejam', 'aqueles', 'mesmo', 'nossa', 'tive', 'estejamos', 'houvemos', 'ele', 'estas', 'sejamos', 'te', 'tivemos', 'teríamos', 'estivéssemos', 'tivera', 'nos', 'se', 'teve', 'minha', 'ela', 'foram', 'houve', 'essa', 'havemos', 'da', 'hão', 'deles', 'a', 'de', 'houvesse', 'teriam', 'meus', 'esteja', 'temos', 'teus', 'estiverem', 'estava', 'muito', 'tivéramos', 'aquilo', 'tenham', 'à', 'elas', 'meu', 'na', 'com', 'tém', 'estive', 'os', 'houverão', 'para', 'tu', 'tínhamos', 'pela', 'não', 'fora', 'nas', 'numa', 'quem', 'teremos', 'haver', 'por', 'sem', 'tiver', 'isso', 'houverá', 'tinha', 'tivessem', 'nós', 'estejam', 'terá', 'houvéramos', 'estamos', 'nosso', 'uma', 'qual', 'houvéssemos', 'fossem', 'hei', 'pelo', 'são', 'essas', 'fosse', 'é', 'eram', 'eu', 'houvera', 'houverei', 'lhe', 'fomos', 'somos', 'houveremos', 'será', 'pelas', 'estou', 'minhas'}
# Removendo stopwords de: cv_texto_pt_tokens -> cv_texto_pt_nostop
# Removendo stopwords de: cv_texto_en_tokens -> cv_texto_en_nostop
# Removendo stopwords de: applicant_conhecimentos_tokens -> applicant_conhecimentos_nostop
# Removendo stopwords de: applicant_certificacoes_tokens -> applicant_certificacoes_nostop
# Removendo stopwords de: atividades_vaga_tokens -> atividades_vaga_nostop
# Removendo stopwords de: competencias_vaga_tokens -> competencias_vaga_nostop
# Removendo stopwords de: titulo_vaga_detalhado_tokens -> titulo_vaga_detalhado_nostop
# Removendo stopwords de: observacoes_vaga_tokens -> observacoes_vaga_nostop
# Removendo stopwords de: comentario_tokens -> comentario_nostop

# %%
print("\n Antes e Depois da remoção de stopwords")
print("Tokens originais: ",df_final['cv_texto_pt_tokens'].iloc[0][:500])
print("Tokens depois da remoção: ",df_final['cv_texto_pt_nostop'].iloc[0][:500])
# Out:
#  Antes e Depois da remoção de stopwords
# Tokens originais:  ['area', 'de', 'atuacao', 'lider', 'de', 'consultoria', 'gerenciamento', 'de', 'projeto', 'lideranca', 'tecnica', 'analista', 'senior', 'resumo', 'de', 'qualificacoes', 'profissional', 'com', '30', 'anos', 'de', 'experiencia', 'na', 'area', 'de', 'ti', 'adquirida', 'em', 'projetos', 'desenvolvidos', 'em', 'empresas', 'nacionais', 'de', 'grande', 'porte', 'e', 'consultorias', 'especializadas', 'solida', 'experiencia', 'na', 'area', 'de', 'tecnologia', 'da', 'informacao', 'atuando', 'como', 'consultor', 'plenosenior', 'liderando', 'equipes', 'de', 'desenvolvimento', 'implantacao', 'e', 'upgrade', 'de', 'sistemas', 'erp', 'crm', 'hcm', 'e', 'campus', 'solution', 'solida', 'experiencia', 'em', 'implantacao', 'de', 'novas', 'funcionalidades', 'e', 'backoffice', 'a', 'solucao', 'peoplesoft', 'forte', 'atuacao', 'junto', 'a', 'clientes', 'internos', 'e', 'externos', 'para', 'implantacao', 'de', 'novos', 'processos', 'de', 'negocio', 'atraves', 'de', 'solucoes', 'erp', '-', 'crm', 'e', 'hcm', 'vivencia', 'nos', 'processos', 'de', 'integracao', 'entre', 'modulos', 'do', 'peoplesoft', 'e', 'sistemas', 'externos', 'e', 'internos', 'experiencia', 'em', 'ferramentas', 'para', 'gerenciamento', 'de', 'projetos', 'msproject', 'e', 'hp', 'ppm', 'experiencia', 'em', 'consultoria', 'remota', 'e', 'monitoramento', 'de', 'processos', 'de', 'producao', 'a', 'distancia', 'vivencia', 'nos', 'processos', 'de', 'analise', 'e', 'levantamento', 'de', 'requisitos', 'detalhamento', 'de', 'escopo', 'definicao', 'de', 'arquitetura', 'elaboracao', 'de', 'especificacoes', 'tecnicasfuncionais', 'e', 'implantacao', 'de', 'processos', 'de', 'producao', 'experiencia', 'na', 'administracao', 'do', 'ambiente', 'e', 'nos', 'processos', 'de', 'administracao', 'de', 'acessos', 'e', 'perfis', 'solida', 'experiencia', 'no', 'suporte', 'a', 'producao', 'administracao', 'de', 'chamados', 'e', 'riscos', 'apresentacao', 'de', 'scorecard', 'semanal', 'e', 'realizacao', 'de', 'treinamento', 'formacao', 'graduacao', '-', 'universidade', 'castelo', 'branco', '-', 'tecnologo', 'em', 'processamento', 'de', 'dados', '-', '1995', 'capacitacao', 'tecnica', 'peoplesoft', 'peopletools', '849', '853', '855', '857', 'peoplecode', 'sqr', 'crystal', 'xml', 'publisher', 'query', 'manager', 'app', 'engine', 'app', 'package', 'process', 'scheduler', 'seguranca', 'app', 'message', 'integration', 'broker', 'workflow', 'tree', 'manager', 'peoplesoft', 'fscm', '89', '91', 'hcm', '90', '92', 'crm', 'e', 'cs', 'microsoft', 'visual', 'basic', 'java', 'xml', 'javascript', 'html', 'css', 'jquery', 'python', 'ios', 'windows', 'linux', 'unix', 'microsoft', 'sql', 'server', 'microsoft', 'access', 'mysql', 'oracle', 'oracle', 'plsql', 'procedures', 'triggers', 'oracle', 'oic', 'cursos', 'de', 'extensao', 'microsoft', 'visual', 'basic', '-', 'nsi', '-', '1995', 'trailhead', 'playground', 'management', '-', 'trailhead', 'by', 'salesforce', '-', 'dez2019', 'nocoes', 'basicas', 'do', 'trailhead', '-', 'trailhead', 'by', 'salesforce', '-', 'dez2019', 'data', 'modeling', '-', 'trailhead', 'by', 'salesforce', '-', 'dez2019', 'salesforce', 'platform', 'basics', '-', 'trailhead', 'by', 'salesforce', '-', 'jan2020', 'crm', 'for', 'salesforce', 'classic', 'trailhead', 'by', 'salesforce', '-', 'jan2020', 'idiomas', 'ingles', '-', 'avancado', 'espanhol', '-', 'intermediario', 'portugues', 'nativo', 'certificados', 'capacitacao', 'peoplesoft', 'formacao', 'tecnica', '-', 'peoplesoft', '1999', 'seguranca', 'da', 'informacao', '-', 'brasilcap', '-', '2009', 'ad', 'administracao', 'de', 'dados', 'brasilcap', '-', '2010', 'oracle', 'hcm', 'cloud', '2019', 'sales', 'specialist', 'assessment', '-', 'ago2020', 'oracle', 'hcm', 'cloud', 'solution', 'engineer', 'specialist', '-', 'jul2020', 'scrum', 'foundation', 'professional', 'certificate', 'spfc', '-', 'certiprof', '-', 'jul2020', 'oracle', 'integration', 'cloud', 'services', 'oic', '-', 'oracle', 'ics', '-', 'udemy', '-', 'dez2020', 'principais', 'projet ...
# Tokens depois da remoção:  ['area', 'atuacao', 'lider', 'consultoria', 'gerenciamento', 'projeto', 'lideranca', 'tecnica', 'analista', 'senior', 'resumo', 'qualificacoes', 'profissional', '30', 'anos', 'experiencia', 'area', 'ti', 'adquirida', 'projetos', 'desenvolvidos', 'empresas', 'nacionais', 'grande', 'porte', 'consultorias', 'especializadas', 'solida', 'experiencia', 'area', 'tecnologia', 'informacao', 'atuando', 'consultor', 'plenosenior', 'liderando', 'equipes', 'desenvolvimento', 'implantacao', 'upgrade', 'sistemas', 'erp', 'crm', 'hcm', 'campus', 'solution', 'solida', 'experiencia', 'implantacao', 'novas', 'funcionalidades', 'backoffice', 'solucao', 'peoplesoft', 'forte', 'atuacao', 'junto', 'clientes', 'internos', 'externos', 'implantacao', 'novos', 'processos', 'negocio', 'atraves', 'solucoes', 'erp', 'crm', 'hcm', 'vivencia', 'processos', 'integracao', 'modulos', 'peoplesoft', 'sistemas', 'externos', 'internos', 'experiencia', 'ferramentas', 'gerenciamento', 'projetos', 'msproject', 'hp', 'ppm', 'experiencia', 'consultoria', 'remota', 'monitoramento', 'processos', 'producao', 'distancia', 'vivencia', 'processos', 'analise', 'levantamento', 'requisitos', 'detalhamento', 'escopo', 'definicao', 'arquitetura', 'elaboracao', 'especificacoes', 'tecnicasfuncionais', 'implantacao', 'processos', 'producao', 'experiencia', 'administracao', 'ambiente', 'processos', 'administracao', 'acessos', 'perfis', 'solida', 'experiencia', 'suporte', 'producao', 'administracao', 'chamados', 'riscos', 'apresentacao', 'scorecard', 'semanal', 'realizacao', 'treinamento', 'formacao', 'graduacao', 'universidade', 'castelo', 'branco', 'tecnologo', 'processamento', 'dados', '1995', 'capacitacao', 'tecnica', 'peoplesoft', 'peopletools', '849', '853', '855', '857', 'peoplecode', 'sqr', 'crystal', 'xml', 'publisher', 'query', 'manager', 'app', 'engine', 'app', 'package', 'process', 'scheduler', 'seguranca', 'app', 'message', 'integration', 'broker', 'workflow', 'tree', 'manager', 'peoplesoft', 'fscm', '89', '91', 'hcm', '90', '92', 'crm', 'cs', 'microsoft', 'visual', 'basic', 'java', 'xml', 'javascript', 'html', 'css', 'jquery', 'python', 'ios', 'windows', 'linux', 'unix', 'microsoft', 'sql', 'server', 'microsoft', 'access', 'mysql', 'oracle', 'oracle', 'plsql', 'procedures', 'triggers', 'oracle', 'oic', 'cursos', 'extensao', 'microsoft', 'visual', 'basic', 'nsi', '1995', 'trailhead', 'playground', 'management', 'trailhead', 'by', 'salesforce', 'dez2019', 'nocoes', 'basicas', 'trailhead', 'trailhead', 'by', 'salesforce', 'dez2019', 'data', 'modeling', 'trailhead', 'by', 'salesforce', 'dez2019', 'salesforce', 'platform', 'basics', 'trailhead', 'by', 'salesforce', 'jan2020', 'crm', 'salesforce', 'classic', 'trailhead', 'by', 'salesforce', 'jan2020', 'idiomas', 'ingles', 'avancado', 'espanhol', 'intermediario', 'portugues', 'nativo', 'certificados', 'capacitacao', 'peoplesoft', 'formacao', 'tecnica', 'peoplesoft', '1999', 'seguranca', 'informacao', 'brasilcap', '2009', 'ad', 'administracao', 'dados', 'brasilcap', '2010', 'oracle', 'hcm', 'cloud', '2019', 'sales', 'specialist', 'assessment', 'ago2020', 'oracle', 'hcm', 'cloud', 'solution', 'engineer', 'specialist', 'jul2020', 'scrum', 'foundation', 'professional', 'certificate', 'spfc', 'certiprof', 'jul2020', 'oracle', 'integration', 'cloud', 'services', 'oic', 'oracle', 'ics', 'udemy', 'dez2020', 'principais', 'projetos', 'implementacao', 'suite', 'financeira', 'peoplesoft', 'erp', 'mbr', 'bh', 'atual', 'vale', 'atuando', 'diretamente', 'modulos', 'ap', 'ar', 'tr', 'consultor', 'tecnico', 'senior', 'implantacao', 'solucao', 'oracle', 'peoplesoft', 'erp', 'crm', 'aga', 'linde', 'health', 'care', 'rj', 'atuando', 'frente', 'tecnica', 'parametrizando', 'customizando', 'desenvolvendo', 'interfaces', 'implantacao', 'solucao', 'oracle', 'peoplesoft', 'erp', 'porto', 'seguro', 'seguros', 'sp', 'atuando', 'diretamente', 'modulo', 'ap', 'consultor', 'senior', 'lider', 'equipe', 'atuei', 'diretamente', 'const ...

# %%
#Definindo a importâncias das palavras utilizando TF-IDF
#Vamos juntar os tokens agora sem stopwords em um string só, porque o TF-IDF não faz a leitura de listas

colunas_nostop_para_str = [col + '_nostop' for col in df_final.columns]
colunas_nostop_para_str = [col for col in colunas_nostop_para_str if col in df_final.columns]

print(colunas_nostop_para_str)

for col in colunas_nostop_para_str:
    nova_coluna_str = col + "_str"
    #Apenas listas que irão ser juntadas
    print(type(col))
    df_final[nova_coluna_str] = df_final[col].apply(lambda tokens: ' '.join(tokens) if isinstance(tokens,list) else '' )
# Out:
# ['comentario_nostop', 'cv_texto_pt_nostop', 'cv_texto_en_nostop', 'applicant_conhecimentos_nostop', 'applicant_certificacoes_nostop', 'titulo_vaga_detalhado_nostop', 'atividades_vaga_nostop', 'competencias_vaga_nostop', 'observacoes_vaga_nostop']
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
df_final.head(3)
# Out:
#   id_vaga                                        titulo_vaga modalidade_vaga  \
# 2    4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 4    4533  2021-2605708-Microfocus Application Life Cycle...
# 6    4534  2021-2605711-Microfocus QTP - UFT Automation T...
#
#           nome_candidato id_candidato        situacao_candidado  \
# 2  Sra. Yasmin Fernandes        25364  Contratado pela Decision
# 4         Arthur Almeida        26338  Contratado pela Decision
# 6       Ana Luiza Vieira        26361           Documentação PJ
#
#   data_candidatura ultima_atualizacao                           comentario  \
# 2       17-03-2021         12-04-2021           Data de Inicio: 12/04/2021
# 4       29-04-2021         18-05-2021
# 6       28-04-2021         11-05-2021  Aguardando confirmação de inicio _
#
#           recrutador  ...                  comentario_nostop  \
# 2   Juliana Cassiano  ...           [data, inicio, 12042021]
# 4      Stella Vieira  ...                                 []
# 6  Manuella Carvalho  ...  [aguardando, confirmacao, inicio]
#
#            comentario_nostop_str  \
# 2           data inicio 12042021
# 4
# 6  aguardando confirmacao inicio
#
#                               cv_texto_pt_nostop_str cv_texto_en_nostop_str  \
# 2  area atuacao lider consultoria gerenciamento p...
# 4  solteiro brasileiro 21061987 habilitacao categ...
# 6  alta mobilidade mudancas viagens objetivo atua...
#
#                   applicant_conhecimentos_nostop_str  \
# 2  peoplesoft peopletools 849 853 855 857 peoplec...
# 4
# 6
#
#   applicant_certificacoes_nostop_str  \
# 2
# 4
# 6
#
#                     titulo_vaga_detalhado_nostop_str  \
# 2  20212607395peoplesoft application enginedomain...
# 4  20212605708microfocus application life cycle m...
# 6   20212605711microfocus qtp uft automation testing
#
#                           atividades_vaga_nostop_str  \
# 2  key skills required the job are peoplesoft app...
# 4  arquiteto foco area automacao requerido experi...
# 6  automacao teste conhecimento codigo experienci...
#
#                         competencias_vaga_nostop_str  \
# 2  recurso peoplesoft responsabilidades projetar ...
# 4  arquiteto foco area automacao requerido experi...
# 6  automacao teste conhecimento codigo experienci...
#
#                          observacoes_vaga_nostop_str
# 2              remoto presencial tempo indeterminado
# 4  atuacao somente horario comercial tempo indete...
# 6
#
# [3 rows x 72 columns]

# %%
df_final.tail(5)
# Out:
#       id_vaga                                        titulo_vaga  \
# 53526   14154                         Gerente de Projetos Sênior
# 53529   14156                        Consultor SAP SD - FSR 4449
# 53589   14166                       Analista de Dados ETL Sênior
# 53590   14167                     Consultor Sênior SAP SD - 1418
# 53622   14173  Especialista em Governança de Segurança da Inf...
#
#       modalidade_vaga     nome_candidato id_candidato  \
# 53526       Cooperado    Aurora Mendonça        49887
# 53529                     Alícia Cardoso        32530
# 53589       Cooperado       Henry Pastor        49917
# 53590                  Ana Sophia Moraes        49791
# 53622                   Augusto Mendonça        49965
#
#                    situacao_candidado data_candidatura ultima_atualizacao  \
# 53526        Contratado pela Decision       10-02-2025         12-02-2025
# 53529        Contratado pela Decision       10-02-2025         13-02-2025
# 53589        Contratado pela Decision       12-02-2025         12-02-2025
# 53590  Não Aprovado pelo Requisitante       13-02-2025         14-02-2025
# 53622        Contratado pela Decision       17-02-2025         17-02-2025
#
#                                               comentario         recrutador  \
# 53526  Início programado para 17/02/2025. Projetos RH...  Melina Montenegro
# 53529                                                        Yasmin da Rosa
# 53589               Cliente Assaí. Início em 03/03/2025.  Melina Montenegro
# 53590  Reprovado pelo busdget, de acordo com tabela d...     Yasmin da Rosa
# 53622  Início programado para 19/02/2025. Assaí Ataca...  Melina Montenegro
#
#        ...                                  comentario_nostop  \
# 53526  ...  [inicio, programado, 17022025, projetos, rh, c...
# 53529  ...                                                 []
# 53589  ...                 [cliente, assai, inicio, 03032025]
# 53590  ...     [reprovado, busdget, acordo, tabela, deloitte]
# 53622  ...  [inicio, programado, 19022025, assai, atacadista]
#
#                                    comentario_nostop_str  \
# 53526  inicio programado 17022025 projetos rh cliente...
# 53529
# 53589                      cliente assai inicio 03032025
# 53590           reprovado busdget acordo tabela deloitte
# 53622        inicio programado 19022025 assai atacadista
#
#       cv_texto_pt_nostop_str cv_texto_en_nostop_str  \
# 53526
# 53529
# 53589
# 53590
# 53622
#
#       applicant_conhecimentos_nostop_str applicant_certificacoes_nostop_str  \
# 53526
# 53529
# 53589
# 53590
# 53622
#
#                    titulo_vaga_detalhado_nostop_str  \
# 53526                       gerente projetos senior
# 53529                     consultor sap sd fsr 4449
# 53589                     analista dados etl senior
# 53590                  consultor senior sap sd 1418
# 53622  especialista governanca seguranca informacao
#
#                               atividades_vaga_nostop_str  \
# 53526      cargo gerente projetos senior inicio imediato
# 53529  modelo alocacao remoto ingles fluente comunica...
# 53589  cargo analista dados etl senior local aricandu...
# 53590  vaga consultor senior sap sd modelo trabalho h...
# 53622  especialista governanca seguranca informacao d...
#
#                             competencias_vaga_nostop_str  \
# 53526  experiencia forte atuacao varejo experiencia m...
# 53529  informacoes sobre habilidade habilidade princi...
# 53589  descricao atividades experiencia manutencao de...
# 53590  conhecimentos tecnicos requeridos consultor se...
# 53622  responsabilidades desenvolver implementar poli...
#
#                              observacoes_vaga_nostop_str
# 53526                              contratacao cooperado
# 53529  substituicao sim outros informacoes adicionais...
# 53589
# 53590  reembolso despesas estacionamento km deloitte ...
# 53622
#
# [5 rows x 72 columns]

# %%
#Combinar textos em uma coluna ( CV + Descrição vaga)
df_final.columns
# Out:
# Index(['id_vaga', 'titulo_vaga', 'modalidade_vaga', 'nome_candidato',
#        'id_candidato', 'situacao_candidado', 'data_candidatura',
#        'ultima_atualizacao', 'comentario', 'recrutador', 'cv_texto_pt',
#        'cv_texto_en', 'applicant_area_atuacao', 'applicant_conhecimentos',
#        'applicant_certificacoes', 'applicant_nivel_profissional',
#        'applicant_nivel_academico', 'applicant_nivel_ingles',
#        'applicant_nivel_espanhol', 'applicant_nome', 'titulo_vaga_detalhado',
#        'cliente_vaga', 'tipo_contratacao', 'pais_vaga', 'estado_vaga',
#        'cidade_vaga', 'nivel_profissional_vaga', 'nivel_academico_vaga',
#        'nivel_ingles_vaga', 'nivel_espanhol_vaga', 'areas_atuacao_vaga',
#        'atividades_vaga', 'competencias_vaga', 'observacoes_vaga', 'pcd_vaga',
#        'aderente', 'cv_texto_pt_limpo', 'cv_texto_en_limpo',
#        'applicant_conhecimentos_limpo', 'applicant_certificacoes_limpo',
#        'atividades_vaga_limpo', 'competencias_vaga_limpo',
#        'titulo_vaga_detalhado_limpo', 'observacoes_vaga_limpo',
#        'comentario_limpo', 'cv_texto_pt_tokens', 'cv_texto_en_tokens',
#        'applicant_conhecimentos_tokens', 'applicant_certificacoes_tokens',
#        'atividades_vaga_tokens', 'competencias_vaga_tokens',
#        'titulo_vaga_detalhado_tokens', 'observacoes_vaga_tokens',
#        'comentario_tokens', 'cv_texto_pt_nostop', 'cv_texto_en_nostop',
#        'applicant_conhecimentos_nostop', 'applicant_certificacoes_nostop',
#        'atividades_vaga_nostop', 'competencias_vaga_nostop',
#        'titulo_vaga_detalhado_nostop', 'observacoes_vaga_nostop',
#        'comentario_nostop', 'comentario_nostop_str', 'cv_texto_pt_nostop_str',
#        'cv_texto_en_nostop_str', 'applicant_conhecimentos_nostop_str',
#        'applicant_certificacoes_nostop_str',
#        'titulo_vaga_detalhado_nostop_str', 'atividades_vaga_nostop_str',
#        'competencias_vaga_nostop_str', 'observacoes_vaga_nostop_str'],
#       dtype='object')

# %%
colunas_texto_combinar = [
                          'cv_texto_pt_nostop_str',
                          'applicant_conhecimentos_nostop_str',
                          'applicant_certificacoes_nostop_str',
                          'atividades_vaga_nostop_str',
                          'competencias_vaga_nostop_str',
                          'titulo_vaga_detalhado_nostop_str',
                          'observacoes_vaga_nostop_str',
                          'comentario_nostop_str' 
                          ]

if colunas_texto_combinar:
    df_final["txt_combinado_para_tfidf"] = df_final[colunas_texto_combinar].agg(' '.join,axis=1)

# %%
df_final.head(3)
# Out:
#   id_vaga                                        titulo_vaga modalidade_vaga  \
# 2    4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 4    4533  2021-2605708-Microfocus Application Life Cycle...
# 6    4534  2021-2605711-Microfocus QTP - UFT Automation T...
#
#           nome_candidato id_candidato        situacao_candidado  \
# 2  Sra. Yasmin Fernandes        25364  Contratado pela Decision
# 4         Arthur Almeida        26338  Contratado pela Decision
# 6       Ana Luiza Vieira        26361           Documentação PJ
#
#   data_candidatura ultima_atualizacao                           comentario  \
# 2       17-03-2021         12-04-2021           Data de Inicio: 12/04/2021
# 4       29-04-2021         18-05-2021
# 6       28-04-2021         11-05-2021  Aguardando confirmação de inicio _
#
#           recrutador  ...          comentario_nostop_str  \
# 2   Juliana Cassiano  ...           data inicio 12042021
# 4      Stella Vieira  ...
# 6  Manuella Carvalho  ...  aguardando confirmacao inicio
#
#                               cv_texto_pt_nostop_str cv_texto_en_nostop_str  \
# 2  area atuacao lider consultoria gerenciamento p...
# 4  solteiro brasileiro 21061987 habilitacao categ...
# 6  alta mobilidade mudancas viagens objetivo atua...
#
#                   applicant_conhecimentos_nostop_str  \
# 2  peoplesoft peopletools 849 853 855 857 peoplec...
# 4
# 6
#
#   applicant_certificacoes_nostop_str  \
# 2
# 4
# 6
#
#                     titulo_vaga_detalhado_nostop_str  \
# 2  20212607395peoplesoft application enginedomain...
# 4  20212605708microfocus application life cycle m...
# 6   20212605711microfocus qtp uft automation testing
#
#                           atividades_vaga_nostop_str  \
# 2  key skills required the job are peoplesoft app...
# 4  arquiteto foco area automacao requerido experi...
# 6  automacao teste conhecimento codigo experienci...
#
#                         competencias_vaga_nostop_str  \
# 2  recurso peoplesoft responsabilidades projetar ...
# 4  arquiteto foco area automacao requerido experi...
# 6  automacao teste conhecimento codigo experienci...
#
#                          observacoes_vaga_nostop_str  \
# 2              remoto presencial tempo indeterminado
# 4  atuacao somente horario comercial tempo indete...
# 6
#
#                             txt_combinado_para_tfidf
# 2  area atuacao lider consultoria gerenciamento p...
# 4  solteiro brasileiro 21061987 habilitacao categ...
# 6  alta mobilidade mudancas viagens objetivo atua...
#
# [3 rows x 73 columns]

# %%
print(df_final['txt_combinado_para_tfidf'].iloc[0])
# Out:
# area atuacao lider consultoria gerenciamento projeto lideranca tecnica analista senior resumo qualificacoes profissional 30 anos experiencia area ti adquirida projetos desenvolvidos empresas nacionais grande porte consultorias especializadas solida experiencia area tecnologia informacao atuando consultor plenosenior liderando equipes desenvolvimento implantacao upgrade sistemas erp crm hcm campus solution solida experiencia implantacao novas funcionalidades backoffice solucao peoplesoft forte atuacao junto clientes internos externos implantacao novos processos negocio atraves solucoes erp crm hcm vivencia processos integracao modulos peoplesoft sistemas externos internos experiencia ferramentas gerenciamento projetos msproject hp ppm experiencia consultoria remota monitoramento processos producao distancia vivencia processos analise levantamento requisitos detalhamento escopo definicao arquitetura elaboracao especificacoes tecnicasfuncionais implantacao processos producao experiencia administracao ambiente processos administracao acessos perfis solida experiencia suporte producao administracao chamados riscos apresentacao scorecard semanal realizacao treinamento formacao graduacao universidade castelo branco tecnologo processamento dados 1995 capacitacao tecnica peoplesoft peopletools 849 853 855 857 peoplecode sqr crystal xml publisher query manager app engine app package process scheduler seguranca app message integration broker workflow tree manager peoplesoft fscm 89 91 hcm 90 92 crm cs microsoft visual basic java xml javascript html css jquery python ios windows linux unix microsoft sql server microsoft access mysql oracle oracle plsql procedures triggers oracle oic cursos extensao microsoft visual basic nsi 1995 trailhead playground management trailhead by salesforce dez2019 nocoes basicas trailhead trailhead by salesforce dez2019 data modeling trailhead by salesforce dez2019 salesforce platform basics trailhead by salesforce jan2020 crm salesforce classic trailhead by salesforce jan2020 idiomas ingles avancado espanhol intermediario portugues nativo certificados capacitacao peoplesoft formacao tecnica peoplesoft 1999 seguranca informacao brasilcap 2009 ad administracao dados brasilcap 2010 oracle hcm cloud 2019 sales specialist assessment ago2020 oracle hcm cloud solution engineer specialist jul2020 scrum foundation professional certificate spfc certiprof jul2020 oracle integration cloud services oic oracle ics udemy dez2020 principais projetos implementacao suite financeira peoplesoft erp mbr bh atual vale atuando diretamente modulos ap ar tr consultor tecnico senior implantacao solucao oracle peoplesoft erp crm aga linde health care rj atuando frente tecnica parametrizando customizando desenvolvendo interfaces implantacao solucao oracle peoplesoft erp porto seguro seguros sp atuando diretamente modulo ap consultor senior lider equipe atuei diretamente construcao interfaces peoplesoft sistema legado implantacao solucao oracle peoplesoft tavex sp atuando diretamente consultor tecnico senior implantacao resolucao 533 anatel peoplesoft crm 2012 claro sp implantacao interface vale escritorio piura peru peoplesoft hcm adam sistema folha pagamento utilizado peru implantacao peoplesoft hcm 92 bbts rj projeto cobranca registrada peoplesoft fscm ar realizado sulamerica rj sustentacao peoplesoft hcm 92 vale brasil rj rollout oracle peoplesoft fscm 91 cbre brasil sp experiencia profissional dbsdigital jan2021 projeto laureate criacao novas bu gl responsavel acompanhamento testes uat1uat2 ajustes tecnicos chamados abertos uat1uat2 manutencao integracoes oic erp clouderp on premise ataway fev2020 dez2020 projeto global cbre implantacao peoplesoft fin 91 projeto remoto responsavel modulo compras po levantamento requisitos workshop funcionalidades levantamento integracoes peoplesoft coupa system testes unitarios testes integrados treinamento projeto br distribuidora integracao oracle oic projeto remoto manutencao integracoes hcm clou ...

# %%
# Aplicar TF-IDF 
from sklearn.feature_extraction.text import TfidfVectorizer
import time

tfidf_vetorizar = TfidfVectorizer(max_features=5000,ngram_range=(1,1)) # uma palavra

start_time = time.time()

tfidf_matrix = tfidf_vetorizar.fit_transform(df_final['txt_combinado_para_tfidf'])
end_time = time.time()

# %%
tfidf_matrix.shape
# Out:
# (7464, 5000)

# %%
# Variaveis categoricas

colunas_categoricas = [  
    'modalidade_vaga', 'tipo_contratacao',
    'pais_vaga', 'estado_vaga', 'cidade_vaga',
    'nivel_profissional_vaga', 'nivel_academico_vaga',
    'nivel_ingles_vaga', 'nivel_espanhol_vaga',
    'areas_atuacao_vaga', 'pcd_vaga',
    'applicant_area_atuacao', 'applicant_nivel_profissional',
    'applicant_nivel_academico', 'applicant_nivel_ingles', 'applicant_nivel_espanhol'
]

df_categoricas = df_final[colunas_categoricas].copy()

# %%
df_categoricas.head(3)
# Out:
#   modalidade_vaga tipo_contratacao pais_vaga estado_vaga cidade_vaga  \
# 2                      PJ/Autônomo    Brasil   São Paulo   São Paulo
# 4                      PJ/Autônomo    Brasil   São Paulo   São Paulo
# 6                      PJ/Autônomo    Brasil   São Paulo   São Paulo
#
#   nivel_profissional_vaga   nivel_academico_vaga nivel_ingles_vaga  \
# 2                          Ensino Médio Completo            Nenhum
# 4                          Ensino Médio Completo           Técnico
# 6                          Ensino Médio Completo           Técnico
#
#   nivel_espanhol_vaga                    areas_atuacao_vaga pcd_vaga  \
# 2              Nenhum  Gestão e Alocação de Recursos de TI-      Não
# 4             Fluente  Gestão e Alocação de Recursos de TI-      Não
# 6              Nenhum  Gestão e Alocação de Recursos de TI-      Não
#
#   applicant_area_atuacao applicant_nivel_profissional  \
# 2          TI - Projetos
# 4
# 6
#
#   applicant_nivel_academico applicant_nivel_ingles applicant_nivel_espanhol
# 2  Ensino Superior Completo               Avançado            Intermediário
# 4
# 6

# %%
for col in colunas_categoricas:
    if df_categoricas[col].isnull().any():
        df_categoricas[col] = df_categoricas[col].fillna('Desconhecido_NA')

df_categoricas.head(10)
# Out:
#    modalidade_vaga       tipo_contratacao pais_vaga estado_vaga cidade_vaga  \
# 2                             PJ/Autônomo    Brasil   São Paulo   São Paulo
# 4                             PJ/Autônomo    Brasil   São Paulo   São Paulo
# 6                             PJ/Autônomo    Brasil   São Paulo   São Paulo
# 8                             PJ/Autônomo    Brasil   São Paulo   São Paulo
# 15                            PJ/Autônomo    Brasil   São Paulo   São Paulo
# 16             CLT            PJ/Autônomo    Brasil   São Paulo   São Paulo
# 19             CLT            PJ/Autônomo    Brasil   São Paulo   São Paulo
# 22             CLT            PJ/Autônomo    Brasil   São Paulo   São Paulo
# 38                  PJ/Autônomo, CLT Full    Brasil   São Paulo   São Paulo
# 54                                Hunting    Brasil   São Paulo   São Paulo
#
#    nivel_profissional_vaga      nivel_academico_vaga nivel_ingles_vaga  \
# 2                              Ensino Médio Completo            Nenhum
# 4                              Ensino Médio Completo           Técnico
# 6                              Ensino Médio Completo           Técnico
# 8                              Ensino Médio Completo           Técnico
# 15                             Ensino Médio Completo           Técnico
# 16                             Ensino Médio Completo           Técnico
# 19                             Ensino Médio Completo           Técnico
# 22                             Ensino Médio Completo           Técnico
# 38                          Ensino Superior Completo            Básico
# 54                             Ensino Médio Completo            Nenhum
#
#    nivel_espanhol_vaga                    areas_atuacao_vaga pcd_vaga  \
# 2               Nenhum  Gestão e Alocação de Recursos de TI-      Não
# 4              Fluente  Gestão e Alocação de Recursos de TI-      Não
# 6               Nenhum  Gestão e Alocação de Recursos de TI-      Não
# 8               Nenhum  Gestão e Alocação de Recursos de TI-      Não
# 15              Nenhum  Gestão e Alocação de Recursos de TI-      Não
# 16              Nenhum  Gestão e Alocação de Recursos de TI-      Não
# 19              Nenhum  Gestão e Alocação de Recursos de TI-      Não
# 22              Nenhum  Gestão e Alocação de Recursos de TI-      Não
# 38              Básico                        TI - Projetos-      Não
# 54              Nenhum             Financeira/Controladoria-      Não
#
#    applicant_area_atuacao applicant_nivel_profissional  \
# 2           TI - Projetos
# 4
# 6
# 8
# 15
# 16
# 19
# 22        Desconhecido_NA              Desconhecido_NA
# 38
# 54
#
#    applicant_nivel_academico applicant_nivel_ingles applicant_nivel_espanhol
# 2   Ensino Superior Completo               Avançado            Intermediário
# 4
# 6
# 8
# 15
# 16
# 19
# 22           Desconhecido_NA        Desconhecido_NA          Desconhecido_NA
# 38
# 54

# %%
df_categoricas_encoded = pd.get_dummies(df_categoricas,columns=colunas_categoricas,drop_first=False,dtype=int)

# %%
df_categoricas_encoded.head(10)
# Out:
#     modalidade_vaga_  modalidade_vaga_CLT  modalidade_vaga_CLT - Estratégico  \
# 2                  1                    0                                  0
# 4                  1                    0                                  0
# 6                  1                    0                                  0
# 8                  1                    0                                  0
# 15                 1                    0                                  0
# 16                 0                    1                                  0
# 19                 0                    1                                  0
# 22                 0                    1                                  0
# 38                 1                    0                                  0
# 54                 1                    0                                  0
#
#     modalidade_vaga_Cooperado  modalidade_vaga_Hunting  modalidade_vaga_PJ  \
# 2                           0                        0                   0
# 4                           0                        0                   0
# 6                           0                        0                   0
# 8                           0                        0                   0
# 15                          0                        0                   0
# 16                          0                        0                   0
# 19                          0                        0                   0
# 22                          0                        0                   0
# 38                          0                        0                   0
# 54                          0                        0                   0
#
#     tipo_contratacao_  tipo_contratacao_CLT Cotas  \
# 2                   0                           0
# 4                   0                           0
# 6                   0                           0
# 8                   0                           0
# 15                  0                           0
# 16                  0                           0
# 19                  0                           0
# 22                  0                           0
# 38                  0                           0
# 54                  0                           0
#
#     tipo_contratacao_CLT Cotas, CLT Full  \
# 2                                      0
# 4                                      0
# 6                                      0
# 8                                      0
# 15                                     0
# 16                                     0
# 19                                     0
# 22                                     0
# 38                                     0
# 54                                     0
#
#     tipo_contratacao_CLT Cotas, Cooperado  ...  \
# 2                                       0  ...
# 4                                       0  ...
# 6                                       0  ...
# 8                                       0  ...
# 15                                      0  ...
# 16                                      0  ...
# 19                                      0  ...
# 22                                      0  ...
# 38                                      0  ...
# 54                                      0  ...
#
#     applicant_nivel_ingles_Fluente  applicant_nivel_ingles_Intermediário  \
# 2                                0                                     0
# 4                                0                                     0
# 6                                0                                     0
# 8                                0                                     0
# 15                               0                                     0
# 16                               0                                     0
# 19                               0                                     0
# 22                               0                                     0
# 38                               0                                     0
# 54                               0                                     0
#
#     applicant_nivel_ingles_Nenhum  applicant_nivel_espanhol_  \
# 2                               0                          0
# 4                               0                          1
# 6                               0                          1
# 8                               0                          1
# 15                              0                          1
# 16                              0                          1
# 19                              0                          1
# 22                              0                          0
# 38                              0                          1
# 54                              0                          1
#
#     applicant_nivel_espanhol_Avançado  applicant_nivel_espanhol_Básico  \
# 2                                   0                                0
# 4                                   0                                0
# 6                                   0                                0
# 8                                   0                                0
# 15                                  0                                0
# 16                                  0                                0
# 19                                  0                                0
# 22                                  0                                0
# 38                                  0                                0
# 54                                  0                                0
#
#     applicant_nivel_espanhol_Desconhecido_NA  \
# 2                                          0
# 4                                          0
# 6                                          0
# 8                                          0
# 15                                         0
# 16                                         0
# 19                                         0
# 22                                         1
# 38                                         0
# 54                                         0
#
#     applicant_nivel_espanhol_Fluente  applicant_nivel_espanhol_Intermediário  \
# 2                                  0                                       1
# 4                                  0                                       0
# 6                                  0                                       0
# 8                                  0                                       0
# 15                                 0                                       0
# 16                                 0                                       0
# 19                                 0                                       0
# 22                                 0                                       0
# 38                                 0                                       0
# 54                                 0                                       0
#
#     applicant_nivel_espanhol_Nenhum
# 2                                 0
# 4                                 0
# 6                                 0
# 8                                 0
# 15                                0
# 16                                0
# 19                                0
# 22                                0
# 38                                0
# 54                                0
#
# [10 rows x 551 columns]

# %%
from scipy.sparse import hstack

#Combinar Features Textuais e Categoricas
print(tfidf_matrix.shape[0])
print(df_categoricas_encoded.shape[0])
# Out:
# 7464
# 7464

# %%
X_final = hstack([tfidf_matrix,df_categoricas_encoded.values],format='csr')
y_final = df_final['aderente'].values

# %%
print(X_final)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1623117 stored elements and shape (7464, 5551)>
#   Coords	Values
#   (0, 222)	0.023758903968633074
#   (0, 226)	0.010410538074038507
#   (0, 240)	0.007974807234801309
#   (0, 241)	0.007158159371506747
#   (0, 243)	0.013830149283867662
#   (0, 250)	0.0065490520955632766
#   (0, 267)	0.008218524820167954
#   (0, 321)	0.04960233728905366
#   (0, 327)	0.036471911650271534
#   (0, 342)	0.014080144805700908
#   (0, 345)	0.012300436692314703
#   (0, 363)	0.017508551205609894
#   (0, 370)	0.013739497555351912
#   (0, 375)	0.010553670882929366
#   (0, 378)	0.02291774076009583
#   (0, 390)	0.010696750562628832
#   (0, 396)	0.009784093743744037
#   (0, 403)	0.030649215403631445
#   (0, 418)	0.013919577744031715
#   (0, 456)	0.01042604612526104
#   (0, 457)	0.01773805885672413
#   (0, 496)	0.012669884831811721
#   (0, 502)	0.02401255445472668
#   (0, 504)	0.017366344572667825
#   (0, 519)	0.008237977043182385
#   :	:
#   (7463, 4304)	0.05093597789917172
#   (7463, 4306)	0.03664079806992337
#   (7463, 4348)	0.029064023543332543
#   (7463, 4512)	0.061183579776210945
#   (7463, 4571)	0.07000135617806805
#   (7463, 4601)	0.05071235069480826
#   (7463, 4637)	0.07890555841431347
#   (7463, 4803)	0.05168182096013656
#   (7463, 4815)	0.04935930615214713
#   (7463, 5000)	1.0
#   (7463, 5019)	1.0
#   (7463, 5035)	1.0
#   (7463, 5063)	1.0
#   (7463, 5183)	1.0
#   (7463, 5194)	1.0
#   (7463, 5200)	1.0
#   (7463, 5210)	1.0
#   (7463, 5216)	1.0
#   (7463, 5272)	1.0
#   (7463, 5284)	1.0
#   (7463, 5324)	1.0
#   (7463, 5507)	1.0
#   (7463, 5516)	1.0
#   (7463, 5540)	1.0
#   (7463, 5547)	1.0

# %%
print(y_final)
# Out:
# [1 1 1 ... 1 0 1]

# %%
from sklearn.model_selection import train_test_split

X_temp,X_test,y_temp,y_test = train_test_split(X_final,y_final,test_size=0.20,random_state=42,stratify=y_final)

X_train,X_val,y_train,y_val = train_test_split(X_temp,y_temp,test_size=0.25,random_state=42,stratify=y_temp)

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (4478, 5551)
# (1493, 5551)
# (1493, 5551)

# %%
print(pd.Series(y_train).value_counts(normalize=True))
# Out:
# 0    0.570567
# 1    0.429433
# Name: proportion, dtype: float64

# %%
print(pd.Series(y_val).value_counts(normalize=True))
# Out:
# 0    0.570663
# 1    0.429337
# Name: proportion, dtype: float64

# %%
print(pd.Series(y_test).value_counts(normalize=True))
# Out:
# 0    0.570663
# 1    0.429337
# Name: proportion, dtype: float64

# %%
# Dados tratados, então agora vamos Construir, treinar e avaliar o modelo
# importando bibliotecas necessárias
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.utils import class_weight # Calcular pesos
from sklearn.metrics import classification_report, confusion_matrix # análise de métricas
import numpy as np
import matplotlib.pyplot as plt

# %%
# Calculando pesos de classe
peso_classe = class_weight.compute_class_weight('balanced',classes=np.unique(y_train),y=y_train)

# %%
print(peso_classe)
# Out:
# [0.87632094 1.16432657]

# %%
# transformando o array em uma bilbioteca para poder buscar com indices
peso_classe_dic = dict(enumerate(peso_classe))
print(peso_classe_dic)
# Out:
# {0: 0.876320939334638, 1: 1.1643265730629224}

# %%
# definindo a aarquitutera da rede neural
input_features = X_train.shape[1]
print(input_features)

model = keras.Sequential(
    [
        keras.Input(shape=(input_features,),sparse=True, name="entrada"),
        layers.Dense(128, activation="relu", name="camada_oculta_1"),
        layers.Dropout(0.4, name='dropout_1'), # 40% de neuronios desligados para evitarmos overfiting
        layers.Dense(64, activation="relu", name="camada_oculta_2"),
        layers.Dropout(0.4, name='dropout_2'), # 40% de neuronios desligados para evitarmos overfiting
        layers.Dense(1, activation="sigmoid", name="camada_saida") # apenas uma camada de saida
    ],
    name="ModeloRanking"
)

model.summary()
# Out:
# 5551
# Model: "ModeloRanking"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ camada_oculta_1 (Dense)         │ (None, 128)            │       710,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ camada_oculta_2 (Dense)         │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ camada_saida (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 718,977 (2.74 MB)
#  Trainable params: 718,977 (2.74 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# definindo métricas, apenas acuracia não seria o ideal, por conta de termos poucos aderentes
metricas = [
    keras.metrics.BinaryAccuracy(name="accuracy"),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
    keras.metrics.AUC(name="auc")
]

otimizar = keras.optimizers.Adam(learning_rate=0.00005) # vamos em passos bem pequenos
# compilar modelo
model.compile(optimizer=otimizar,loss="binary_crossentropy",metrics=metricas) # binary_crossentropy -> função de perda
print("modelo compilado!")
# Out:
# modelo compilado!

# %%
# treinando o modelo
print("Iniciando treinamento do modelo")
epocas = 100
batch_size = 128

# se não tiver melhora, vamos utilizar um callback
parar_antes = tf.keras.callbacks.EarlyStopping(monitor='val_auc',patience=7,mode='max',restore_best_weights=True)

inicio_treino = time.time()

hist = model.fit(
    X_train,
    y_train,
    batch_size = batch_size,
    epochs = epocas,
    validation_data = (X_val,y_val),
    class_weight = peso_classe_dic,
    callbacks = [parar_antes],
    verbose = 1
)

final_treino = time.time()

print("Treinamento concluido")
print("Tempo em segundos ", final_treino - inicio_treino)
# Out:
# Iniciando treinamento do modelo
# Epoch 1/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.5668 - auc: 0.5383 - loss: 0.6936 - precision: 0.4865 - recall: 0.0747 - val_accuracy: 0.5834 - val_auc: 0.6634 - val_loss: 0.6802 - val_precision: 0.6173 - val_recall: 0.0780
# Epoch 2/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5855 - auc: 0.6041 - loss: 0.6870 - precision: 0.5752 - recall: 0.1451 - val_accuracy: 0.6222 - val_auc: 0.7047 - val_loss: 0.6765 - val_precision: 0.6825 - val_recall: 0.2246
# Epoch 3/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5989 - auc: 0.6243 - loss: 0.6849 - precision: 0.5952 - recall: 0.2205 - val_accuracy: 0.6490 - val_auc: 0.7279 - val_loss: 0.6718 - val_precision: 0.7067 - val_recall: 0.3120
# Epoch 4/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6139 - auc: 0.6523 - loss: 0.6808 - precision: 0.6208 - recall: 0.2755 - val_accuracy: 0.6631 - val_auc: 0.7419 - val_loss: 0.6655 - val_precision: 0.7018 - val_recall: 0.3744
# Epoch 5/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.6370 - auc: 0.6865 - loss: 0.6732 - precision: 0.6555 - recall: 0.3129 - val_accuracy: 0.6725 - val_auc: 0.7513 - val_loss: 0.6592 - val_precision: 0.6969 - val_recall: 0.4197
# Epoch 6/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6489 - auc: 0.7134 - loss: 0.6693 - precision: 0.6630 - recall: 0.4107 - val_accuracy: 0.6892 - val_auc: 0.7600 - val_loss: 0.6523 - val_precision: 0.7082 - val_recall: 0.4696
# Epoch 7/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6618 - auc: 0.7149 - loss: 0.6614 - precision: 0.6597 - recall: 0.4429 - val_accuracy: 0.6932 - val_auc: 0.7665 - val_loss: 0.6432 - val_precision: 0.7184 - val_recall: 0.4696
# Epoch 8/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.6768 - auc: 0.7468 - loss: 0.6517 - precision: 0.6829 - recall: 0.4808 - val_accuracy: 0.7073 - val_auc: 0.7725 - val_loss: 0.6361 - val_precision: 0.7056 - val_recall: 0.5460
# Epoch 9/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7006 - auc: 0.7572 - loss: 0.6399 - precision: 0.6948 - recall: 0.5340 - val_accuracy: 0.7220 - val_auc: 0.7778 - val_loss: 0.6276 - val_precision: 0.7140 - val_recall: 0.5881
# Epoch 10/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7045 - auc: 0.7674 - loss: 0.6312 - precision: 0.6878 - recall: 0.5746 - val_accuracy: 0.7267 - val_auc: 0.7843 - val_loss: 0.6175 - val_precision: 0.7186 - val_recall: 0.5975
# Epoch 11/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7113 - auc: 0.7646 - loss: 0.6278 - precision: 0.6997 - recall: 0.5962 - val_accuracy: 0.7361 - val_auc: 0.7904 - val_loss: 0.6076 - val_precision: 0.7266 - val_recall: 0.6178
# Epoch 12/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7304 - auc: 0.7930 - loss: 0.6081 - precision: 0.7098 - recall: 0.6227 - val_accuracy: 0.7475 - val_auc: 0.7960 - val_loss: 0.5998 - val_precision: 0.7268 - val_recall: 0.6599
# Epoch 13/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7219 - auc: 0.7890 - loss: 0.6048 - precision: 0.6914 - recall: 0.6523 - val_accuracy: 0.7562 - val_auc: 0.8018 - val_loss: 0.5881 - val_precision: 0.7443 - val_recall: 0.6583
# Epoch 14/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7431 - auc: 0.8066 - loss: 0.5884 - precision: 0.7217 - recall: 0.6579 - val_accuracy: 0.7622 - val_auc: 0.8074 - val_loss: 0.5793 - val_precision: 0.7440 - val_recall: 0.6802
# Epoch 15/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7376 - auc: 0.8090 - loss: 0.5793 - precision: 0.7067 - recall: 0.6709 - val_accuracy: 0.7622 - val_auc: 0.8123 - val_loss: 0.5703 - val_precision: 0.7432 - val_recall: 0.6817
# Epoch 16/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7607 - auc: 0.8209 - loss: 0.5648 - precision: 0.7270 - recall: 0.6905 - val_accuracy: 0.7609 - val_auc: 0.8164 - val_loss: 0.5609 - val_precision: 0.7407 - val_recall: 0.6817
# Epoch 17/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7631 - auc: 0.8322 - loss: 0.5520 - precision: 0.7316 - recall: 0.7009 - val_accuracy: 0.7616 - val_auc: 0.8206 - val_loss: 0.5509 - val_precision: 0.7436 - val_recall: 0.6786
# Epoch 18/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7590 - auc: 0.8294 - loss: 0.5473 - precision: 0.7310 - recall: 0.6966 - val_accuracy: 0.7642 - val_auc: 0.8240 - val_loss: 0.5462 - val_precision: 0.7350 - val_recall: 0.7051
# Epoch 19/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7682 - auc: 0.8414 - loss: 0.5330 - precision: 0.7466 - recall: 0.7104 - val_accuracy: 0.7689 - val_auc: 0.8271 - val_loss: 0.5357 - val_precision: 0.7517 - val_recall: 0.6895
# Epoch 20/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7733 - auc: 0.8366 - loss: 0.5357 - precision: 0.7664 - recall: 0.7066 - val_accuracy: 0.7689 - val_auc: 0.8297 - val_loss: 0.5286 - val_precision: 0.7475 - val_recall: 0.6973
# Epoch 21/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7801 - auc: 0.8481 - loss: 0.5163 - precision: 0.7566 - recall: 0.7218 - val_accuracy: 0.7696 - val_auc: 0.8321 - val_loss: 0.5232 - val_precision: 0.7415 - val_recall: 0.7114
# Epoch 22/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7920 - auc: 0.8574 - loss: 0.5052 - precision: 0.7648 - recall: 0.7374 - val_accuracy: 0.7716 - val_auc: 0.8346 - val_loss: 0.5171 - val_precision: 0.7435 - val_recall: 0.7145
# Epoch 23/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7951 - auc: 0.8632 - loss: 0.4967 - precision: 0.7748 - recall: 0.7458 - val_accuracy: 0.7770 - val_auc: 0.8366 - val_loss: 0.5094 - val_precision: 0.7584 - val_recall: 0.7051
# Epoch 24/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8064 - auc: 0.8748 - loss: 0.4811 - precision: 0.7868 - recall: 0.7516 - val_accuracy: 0.7783 - val_auc: 0.8379 - val_loss: 0.5067 - val_precision: 0.7516 - val_recall: 0.7223
# Epoch 25/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7986 - auc: 0.8630 - loss: 0.4832 - precision: 0.7583 - recall: 0.7579 - val_accuracy: 0.7763 - val_auc: 0.8400 - val_loss: 0.5021 - val_precision: 0.7456 - val_recall: 0.7270
# Epoch 26/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8078 - auc: 0.8737 - loss: 0.4748 - precision: 0.7856 - recall: 0.7755 - val_accuracy: 0.7790 - val_auc: 0.8417 - val_loss: 0.4947 - val_precision: 0.7605 - val_recall: 0.7083
# Epoch 27/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8045 - auc: 0.8789 - loss: 0.4637 - precision: 0.7823 - recall: 0.7369 - val_accuracy: 0.7790 - val_auc: 0.8434 - val_loss: 0.4922 - val_precision: 0.7528 - val_recall: 0.7223
# Epoch 28/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7921 - auc: 0.8658 - loss: 0.4755 - precision: 0.7561 - recall: 0.7571 - val_accuracy: 0.7790 - val_auc: 0.8449 - val_loss: 0.4863 - val_precision: 0.7587 - val_recall: 0.7114
# Epoch 29/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8140 - auc: 0.8899 - loss: 0.4417 - precision: 0.7901 - recall: 0.7715 - val_accuracy: 0.7850 - val_auc: 0.8461 - val_loss: 0.4878 - val_precision: 0.7492 - val_recall: 0.7504
# Epoch 30/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8207 - auc: 0.8972 - loss: 0.4371 - precision: 0.7932 - recall: 0.8027 - val_accuracy: 0.7803 - val_auc: 0.8471 - val_loss: 0.4796 - val_precision: 0.7604 - val_recall: 0.7129
# Treinamento concluido
# Tempo em segundos  24.760225534439087

# %%
# Agora que treinamos o modelo com os dados de treino, vamos avaliar com os dados de testes
resultados_testes = model.evaluate(
    X_test,
    y_test,
    batch_size = batch_size,
    verbose = 0
)

# %%
print(resultados_testes)
# Out:
# [0.48790687322616577, 0.7816476821899414, 0.7655986547470093, 0.7082683444023132, 0.8420656323432922]

# %%
# Fazer previsões de probabilidade no conjunto de teste
y_pred_proba_test = model.predict(X_test, batch_size = BATCH_SIZE if 'BATCH_SIZE' in locals() else 128)
# Converter probabilidades em classes (0 ou 1) usando um limiar (threshold) de 0.4
y_pred_class_test = (y_pred_proba_test > 0.4).astype(int)

print("\nMatriz de Confusão (Conjunto de Teste):")
print(confusion_matrix(y_test, y_pred_class_test))

print("\nRelatório de Classificação (Conjunto de Teste):")
print(classification_report(y_test, y_pred_class_test, target_names=['Nao Aderente (0)', 'Aderente (1)']))
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# Matriz de Confusão (Conjunto de Teste):
# [[631 221]
#  [135 506]]
#
# Relatório de Classificação (Conjunto de Teste):
#                   precision    recall  f1-score   support
#
# Nao Aderente (0)       0.82      0.74      0.78       852
#     Aderente (1)       0.70      0.79      0.74       641
#
#         accuracy                           0.76      1493
#        macro avg       0.76      0.77      0.76      1493
#     weighted avg       0.77      0.76      0.76      1493

# %%
path = "modelo_final.keras"
model.save(path)

# %%
import joblib

path = "tfidf_vectorizer.pkl"
joblib.dump(tfidf_vetorizar, path)
# Out:
# ['tfidf_vectorizer.pkl']

# %%
path = 'colunas_categoricas_final.pkl'
pathOriginal = 'colunas_categoricas_originais.pkl'

joblib.dump(df_categoricas_encoded.columns.tolist(), path)
joblib.dump(colunas_categoricas,pathOriginal)
# Out:
# ['colunas_categoricas_originais.pkl']
